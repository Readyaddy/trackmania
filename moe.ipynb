# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
from tmrl import get_environment
import os
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)


class SimpleDQN(nn.Module):
    def __init__(self, h, w, outputs):
        super(SimpleDQN, self).__init__()
        
        # Simplified convolutional layers
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        
        # Calculate the size of flattened features
        conv_out_size = self._get_conv_out(h, w)
        
        # Simplified fully connected layers
        self.fc1 = nn.Linear(conv_out_size + 9, 512)
        self.fc2 = nn.Linear(512, outputs)

    def _get_conv_out(self, h, w):
        o = F.relu(self.conv1(torch.zeros(1, 4, h, w)))
        o = F.relu(self.conv2(o))
        o = F.relu(self.conv3(o))
        return int(np.prod(o.size()))

    def forward(self, x, additional_inputs):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = torch.cat((x, additional_inputs), dim=1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

class SimpleDQNAgent:
    def __init__(self, n_actions, memory_size=100000, batch_size=32, gamma=0.99, epsilon_start=1.0, epsilon_final=0.01, epsilon_decay=0.995, learning_rate=0.001):
        self.n_actions = n_actions
        self.memory = deque(maxlen=memory_size)
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_final = epsilon_final
        self.epsilon_decay = epsilon_decay
        self.steps = 0

        self.policy_net = SimpleDQN(64, 64, n_actions).to(device)
        self.target_net = SimpleDQN(64, 64, n_actions).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=learning_rate)

    def select_action(self, state):
        if random.random() > self.epsilon:
            with torch.no_grad():
                image = torch.FloatTensor(state[3]).unsqueeze(0).to(device)
                additional = torch.FloatTensor(np.concatenate([state[0], state[1], state[2], state[4], state[5]])).unsqueeze(0).to(device)
                return self.policy_net(image, additional).max(1)[1].view(1, 1)
        else:
            return torch.tensor([[random.randrange(self.n_actions)]], device=device, dtype=torch.long)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        batch = random.sample(self.memory, self.batch_size)
        state_batch, action_batch, reward_batch, next_state_batch, done_batch = zip(*batch)

        state_image_batch = torch.FloatTensor(np.stack([s[3] for s in state_batch])).to(device)
        state_additional_batch = torch.FloatTensor(np.stack([np.concatenate([s[0], s[1], s[2], s[4], s[5]]) for s in state_batch])).to(device)

        next_state_image_batch = torch.FloatTensor(np.stack([s[3] for s in next_state_batch])).to(device)
        next_state_additional_batch = torch.FloatTensor(np.stack([np.concatenate([s[0], s[1], s[2], s[4], s[5]]) for s in next_state_batch])).to(device)

        action_batch = torch.LongTensor(action_batch).to(device)
        reward_batch = torch.FloatTensor(reward_batch).to(device)
        done_batch = torch.FloatTensor(done_batch).to(device)

        q_values = self.policy_net(state_image_batch, state_additional_batch).gather(1, action_batch.unsqueeze(1))
        next_q_values = self.target_net(next_state_image_batch, next_state_additional_batch).max(1)[0].detach()
        expected_q_values = reward_batch + (1 - done_batch) * self.gamma * next_q_values

        loss = F.smooth_l1_loss(q_values, expected_q_values.unsqueeze(1))

        self.optimizer.zero_grad()
        loss.backward()
        for param in self.policy_net.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()

        self.epsilon = max(self.epsilon_final, self.epsilon * self.epsilon_decay)

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def save_checkpoint(self, episode, directory="checkpoints_simple_left_turn"):
        if not os.path.exists(directory):
            os.makedirs(directory)
        checkpoint = {
            'episode': episode,
            'model_state_dict': self.policy_net.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'epsilon': self.epsilon,
            'steps': self.steps
        }
        filename = os.path.join(directory, f"checkpoint_episode_{episode}_step_{self.steps}.pth")
        torch.save(checkpoint, filename)
        print(f"Checkpoint saved: {filename}")

    def load_checkpoint(self, filename):
        checkpoint = torch.load(filename)
        self.policy_net.load_state_dict(checkpoint['model_state_dict'])
        self.target_net.load_state_dict(checkpoint['model_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.epsilon = checkpoint['epsilon']
        self.steps = checkpoint['steps']
        return checkpoint['episode']
def preprocess_observation(obs):
    speed = np.array(obs[0]).flatten()
    steering = np.array(obs[1]).flatten()
    gyro = np.array(obs[2]).flatten()
    image = np.array(obs[3]).astype(np.float32) / 255.0
    prev_action = np.array(obs[4]).flatten()
    action = np.array(obs[5]).flatten()
    
    speed = np.clip(speed / 300.0, -1, 1)
    steering = np.clip(steering / np.pi, -1, 1)
    gyro = np.clip(gyro / np.pi, -1, 1)
    prev_action = np.clip(prev_action, -1, 1)
    action = np.clip(action, -1, 1)
    
    return (speed, steering, gyro, image, prev_action, action)

def env_action_to_agent_action(env_action, n_actions):
    if isinstance(env_action, (int, np.integer)):
        return env_action
    elif isinstance(env_action, (float, np.float32, np.float64)):
        return int((env_action + 1) * (n_actions - 1) / 2)
    elif isinstance(env_action, np.ndarray):
        return np.argmax(env_action)
    else:
        raise ValueError(f"Unexpected action type: {type(env_action)}")

def agent_action_to_env_action(agent_action, n_actions):
    steering = (agent_action * 2 / (n_actions - 1)) - 1
    throttle = 1.0
    brake = 0.0
    return [throttle, brake, steering]

def detect_crash(obs, prev_obs, speed_threshold=1.0):
    if prev_obs is None:
        return False
    
    current_speed = np.linalg.norm(obs[0])
    prev_speed = np.linalg.norm(prev_obs[0])
    
    if prev_speed - current_speed > speed_threshold:
        return True
    
    return False

def train(env, agent, num_episodes, max_steps_per_episode):
    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = preprocess_observation(obs)
        total_reward = 0
        episode_start_time = time.time()
        prev_obs = None
        crashes = 0

        for step in range(max_steps_per_episode):
            agent_action = agent.select_action(state)
            env_action = agent_action_to_env_action(agent_action.item(), agent.n_actions)
            next_obs, env_reward, terminated, truncated, _ = env.step(env_action)
            next_state = preprocess_observation(next_obs)
            
            if detect_crash(next_obs, prev_obs):
                crashes += 1
                env_reward-= 10
            done = terminated or truncated
            
            elapsed_time = time.time() - episode_start_time
            time_factor = 1 / (elapsed_time + 1)
            reward = (env_reward)
            
            agent.remember(state, agent_action.item(), reward, next_state, done)
            agent.replay()
            
            state = next_state
            prev_obs = next_obs
            total_reward += reward

            agent.steps += 1

            if agent.steps % 1000 == 0:
                agent.save_checkpoint(episode)

            if done:
                break
        # total_reward-= 20*crashes
        if episode % 10 == 0:
            agent.update_target_network()

        print(f"Episode {episode}, Total Reward: {total_reward:.2f}, Crashes: {crashes}, Epsilon: {agent.epsilon:.4f}, Time: {elapsed_time:.2f}s")

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
from tmrl import get_environment
import os
import time
import wandb
from collections import deque, defaultdict
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# SimpleDQN and SimpleDQNAgent classes remain the same as in the provided code

class Router(nn.Module):
    def __init__(self, num_experts):
        super(Router, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        
        # Calculate the size of flattened features
        self.conv_out_size = self._get_conv_out(64, 64)
        
        self.fc1 = nn.Linear(self.conv_out_size + 9, 512)  # +9 for additional inputs
        self.fc2 = nn.Linear(512, num_experts)

    def _get_conv_out(self, h, w):
        o = F.relu(self.conv1(torch.zeros(1, 4, h, w)))
        o = F.relu(self.conv2(o))
        o = F.relu(self.conv3(o))
        return int(np.prod(o.size()))

    def forward(self, x, additional_inputs):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = torch.cat((x, additional_inputs), dim=1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

class MixtureOfExpertsDQN:
    def __init__(self, expert_agents, learning_rate=0.001, gamma=0.99, epsilon_start=1.0, epsilon_final=0.01, epsilon_decay=0.995):
        self.expert_agents = expert_agents
        self.num_experts = len(expert_agents)
        self.router = Router(self.num_experts).to(device)
        self.target_router = Router(self.num_experts).to(device)
        self.target_router.load_state_dict(self.router.state_dict())
        self.optimizer = optim.Adam(self.router.parameters(), lr=learning_rate)
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_final = epsilon_final
        self.epsilon_decay = epsilon_decay
        self.memory = deque(maxlen=100000)

    def select_action(self, state):
        if random.random() > self.epsilon:
            with torch.no_grad():
                image = torch.FloatTensor(state[3]).unsqueeze(0).to(device)
                additional_inputs = torch.FloatTensor(np.concatenate([state[0], state[1], state[2], state[4], state[5]])).unsqueeze(0).to(device)
                expert_probs = self.router(image, additional_inputs)
                expert_idx = expert_probs.argmax().item()
        else:
            expert_idx = random.randint(0, self.num_experts - 1)
        
        selected_expert = self.expert_agents[expert_idx]
        return selected_expert.select_action(state), expert_idx

    def remember(self, state, expert_idx, reward, next_state, done):
        self.memory.append((state, expert_idx, reward, next_state, done))

    def train_step(self, batch_size):
        if len(self.memory) < batch_size:
            return None

        batch = random.sample(self.memory, batch_size)
        states, expert_indices, rewards, next_states, dones = zip(*batch)

        states_image = torch.FloatTensor(np.array([state[3] for state in states])).to(device)
        states_additional = torch.FloatTensor(np.array([np.concatenate([state[0], state[1], state[2], state[4], state[5]]) for state in states])).to(device)
        next_states_image = torch.FloatTensor(np.array([state[3] for state in next_states])).to(device)
        next_states_additional = torch.FloatTensor(np.array([np.concatenate([state[0], state[1], state[2], state[4], state[5]]) for state in next_states])).to(device)
        expert_indices = torch.LongTensor(expert_indices).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(dones).to(device)

        current_q_values = self.router(states_image, states_additional).gather(1, expert_indices.unsqueeze(1))
        next_q_values = self.target_router(next_states_image, next_states_additional).max(1)[0].detach()
        target_q_values = rewards + (1 - dones) * self.gamma * next_q_values

        loss = F.smooth_l1_loss(current_q_values, target_q_values.unsqueeze(1))

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.epsilon = max(self.epsilon_final, self.epsilon * self.epsilon_decay)

        return loss.item()

    def update_target_network(self):
        self.target_router.load_state_dict(self.router.state_dict())

    def save_model(self, path):
        if not os.path.exists(path):
            os.makedirs(path)
        torch.save({
            'router_state_dict': self.router.state_dict(),
            'target_router_state_dict': self.target_router.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'epsilon': self.epsilon,
        }, os.path.join(path, 'moe_model.pth'))

    def load_model(self, path):
        checkpoint = torch.load(os.path.join(path, 'moe_model.pth'))
        self.router.load_state_dict(checkpoint['router_state_dict'])
        self.target_router.load_state_dict(checkpoint['target_router_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.epsilon = checkpoint['epsilon']
def train_mixture_of_experts(env, moe_agent, num_episodes, max_steps_per_episode, batch_size):
    total_crashes = 0
    total_time = 0
    total_loss = 0
    expert_usage = [0] * moe_agent.num_experts

    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = preprocess_observation(obs)
        total_reward = 0
        episode_crashes = 0
        episode_loss = 0
        episode_start_time = time.time()
        prev_obs = None
        episode_expert_usage = [0] * moe_agent.num_experts
        crash_reward = 0

        for step in range(max_steps_per_episode):
            agent_action, expert_idx = moe_agent.select_action(state)
            expert_usage[expert_idx] += 1
            episode_expert_usage[expert_idx] += 1
            env_action = agent_action_to_env_action(agent_action.item(), moe_agent.expert_agents[0].n_actions)
            next_obs, env_reward, terminated, truncated, _ = env.step(env_action)
            next_state = preprocess_observation(next_obs)
            done = terminated or truncated

            if detect_crash(next_obs, prev_obs):
                episode_crashes += 1
                crash_penalty = -0.2  # Penalty for crashing
                env_reward += crash_penalty
                crash_reward += crash_penalty

            moe_agent.remember(state, expert_idx, env_reward, next_state, done)

            loss = moe_agent.train_step(batch_size)
            if loss is not None:
                episode_loss += loss

            state = next_state
            prev_obs = next_obs
            total_reward += env_reward

            if done:
                break

        episode_time = time.time() - episode_start_time
        total_time += episode_time
        total_crashes += episode_crashes
        total_loss += episode_loss

        if episode % 10 == 0:
            moe_agent.update_target_network()

        # Calculate expert usage ratio
        total_expert_usage = sum(episode_expert_usage)
        expert_usage_ratio = [usage / total_expert_usage for usage in episode_expert_usage]
        if (episode + 1) % 100 == 0:
            save_path = f"router_model_episode_{episode + 1}"
            moe_agent.save_model(save_path)
            print(f"Router model saved at episode {episode + 1}")
        # Print episode information including loss and crash reward
        print(f"Episode {episode}, Total Reward: {total_reward:.2f}, Loss: {episode_loss:.4f}, Crashes: {episode_crashes}, Crash Reward: {crash_reward:.2f}, Time: {episode_time:.2f}s")

        # Log metrics to wandb
        wandb.log({
            "episode": episode,
            "total_reward": total_reward,
            "loss": episode_loss,
            "crashes": episode_crashes,
            "crash_reward": crash_reward,
            "time": episode_time,
            "average_reward": total_reward / (step + 1),
            "total_crashes": total_crashes,
            "total_time": total_time,
            "episode_duration": episode_time,
            "experts_used": sum(1 for usage in episode_expert_usage if usage > 0),
        })

        for i, usage in enumerate(episode_expert_usage):
            wandb.log({
                f"expert_{i}_usage": usage,
                f"expert_{i}_usage_ratio": expert_usage_ratio[i]
            })

    # Print final training statistics
    print(f"Training completed. Total crashes: {total_crashes}, Total time: {total_time:.2f}s, Average loss: {total_loss/num_episodes:.4f}")

def test_mixture_of_experts(env, moe_agent, num_episodes, max_steps_per_episode):
    total_rewards = []
    total_crashes = 0
    total_time = 0
    expert_usage = [0] * moe_agent.num_experts
    
    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = preprocess_observation(obs)
        total_reward = 0
        episode_crashes = 0
        episode_start_time = time.time()
        prev_obs = None
        episode_expert_usage = [0] * moe_agent.num_experts
        
        for step in range(max_steps_per_episode):
            agent_action, expert_idx = moe_agent.select_action(state)
            expert_usage[expert_idx] += 1
            episode_expert_usage[expert_idx] += 1
            env_action = agent_action_to_env_action(agent_action.item(), moe_agent.expert_agents[0].n_actions)
            next_obs, reward, terminated, truncated, _ = env.step(env_action)
            next_state = preprocess_observation(next_obs)
            done = terminated or truncated

            if detect_crash(next_obs, prev_obs):
                episode_crashes += 1

            state = next_state
            prev_obs = next_obs
            total_reward += reward

            if done:
                break

        episode_time = time.time() - episode_start_time
        total_time += episode_time
        total_crashes += episode_crashes
        total_rewards.append(total_reward)

        # Calculate expert usage ratio
        total_expert_usage = sum(episode_expert_usage)
        expert_usage_ratio = [usage / total_expert_usage for usage in episode_expert_usage]

        # Log test metrics to wandb
        wandb.log({
            "test_episode": episode,
            "test_total_reward": total_reward,
            "test_crashes": episode_crashes,
            "test_time": episode_time,
            "test_average_reward": total_reward / (step + 1),
            "test_total_crashes": total_crashes,
            "test_total_time": total_time,
            "test_episode_duration": episode_time,
            "test_experts_used": sum(1 for usage in episode_expert_usage if usage > 0),
        })

        for i, usage in enumerate(episode_expert_usage):
            wandb.log({
                f"test_expert_{i}_usage": usage,
                f"test_expert_{i}_usage_ratio": expert_usage_ratio[i]
            })

        print(f"Test Episode {episode}, Total Reward: {total_reward:.2f}, Crashes: {episode_crashes}, Time: {episode_time:.2f}s")

    avg_reward = sum(total_rewards) / len(total_rewards)
    print(f"Average Reward over {num_episodes} episodes: {avg_reward:.2f}")
    wandb.log({"test_average_reward_overall": avg_reward})

# The test_mixture_of_experts function remains the same

import warnings
warnings.filterwarnings("ignore")

if __name__ == "__main__":
    env = get_environment()
    n_actions = 3

    # Initialize wandb
    wandb.init(project="moe-router-scratch")

    # Load your three pre-trained expert agents
    expert1 = SimpleDQNAgent(n_actions)
    expert1.load_checkpoint("checkpoints_simple/checkpoint_episode_177_step_30000.pth")
    expert2 = SimpleDQNAgent(n_actions)
    expert2.load_checkpoint("checkpoints_simple_left_turn/checkpoint_episode_179_step_78000.pth")
    expert3 = SimpleDQNAgent(n_actions)
    expert3.load_checkpoint("checkpoints_simple_right_turn/checkpoint_episode_179_step_34000.pth")

    moe_agent = MixtureOfExpertsDQN([expert1, expert2, expert3])

    # Train the Mixture of Experts with alternating updates
    train_mixture_of_experts(env, moe_agent, num_episodes=4000, max_steps_per_episode=1000000,batch_size=32)

    # Test the Mixture of Experts
    test_mixture_of_experts(env, moe_agent, num_episodes=100, max_steps_per_episode=5000)

    # Save the final model

    # Close wandb run
    wandb.finish()
# Out:
# cuda
# cuda
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: adamyvashisth (adamyvashisth-indian-institute-of-technology-roorkee). Use `wandb login --relogin` to force relogin
# wandb version 0.17.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>f:\fun\trackmania\wandb\run-20240910_012158-8077yatl</code>
# Syncing run <strong><a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/moe-router-scratch/runs/8077yatl' target="_blank">super-hill-3</a></strong> to <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/moe-router-scratch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/moe-router-scratch' target="_blank">https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/moe-router-scratch</a>
#  View run at <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/moe-router-scratch/runs/8077yatl' target="_blank">https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/moe-router-scratch/runs/8077yatl</a>
# Episode 0, Total Reward: -0.38, Loss: 0.0371, Crashes: 4, Crash Reward: -0.80, Time: 5.04s
# Episode 1, Total Reward: 77.16, Loss: 0.1430, Crashes: 25, Crash Reward: -5.00, Time: 51.23s
# Episode 2, Total Reward: 2.58, Loss: 0.0099, Crashes: 6, Crash Reward: -1.20, Time: 4.84s
# Episode 3, Total Reward: 19.92, Loss: 0.0530, Crashes: 10, Crash Reward: -2.00, Time: 20.97s
# Episode 4, Total Reward: 578.00, Loss: 0.1097, Crashes: 33, Crash Reward: -6.60, Time: 44.33s
# Episode 5, Total Reward: 8.14, Loss: 46.8231, Crashes: 12, Crash Reward: -2.40, Time: 6.54s
# Episode 6, Total Reward: 0.62, Loss: 0.0438, Crashes: 5, Crash Reward: -1.00, Time: 4.57s
# Episode 7, Total Reward: -0.80, Loss: 0.0296, Crashes: 4, Crash Reward: -0.80, Time: 4.43s
# Episode 8, Total Reward: -1.00, Loss: 0.0205, Crashes: 5, Crash Reward: -1.00, Time: 4.32s
# Episode 9, Total Reward: 77.60, Loss: 109.3447, Crashes: 35, Crash Reward: -7.00, Time: 44.51s
# Episode 10, Total Reward: 1.57, Loss: 15.6411, Crashes: 7, Crash Reward: -1.40, Time: 4.48s
# Episode 11, Total Reward: 1.84, Loss: 0.1389, Crashes: 6, Crash Reward: -1.20, Time: 4.46s
# Episode 12, Total Reward: 4.39, Loss: 15.7343, Crashes: 12, Crash Reward: -2.40, Time: 7.93s
# Episode 13, Total Reward: 1.49, Loss: 0.0489, Crashes: 5, Crash Reward: -1.00, Time: 4.33s
# Episode 14, Total Reward: 1.77, Loss: 0.0489, Crashes: 6, Crash Reward: -1.20, Time: 4.40s
# Episode 15, Total Reward: 3.33, Loss: 0.0466, Crashes: 4, Crash Reward: -0.80, Time: 4.67s
# Episode 16, Total Reward: 76.20, Loss: 62.9757, Crashes: 42, Crash Reward: -8.40, Time: 29.85s
# Episode 17, Total Reward: 19.97, Loss: 62.8193, Crashes: 14, Crash Reward: -2.80, Time: 11.68s
# Episode 18, Total Reward: 20.79, Loss: 62.9091, Crashes: 15, Crash Reward: -3.00, Time: 17.49s
# Episode 19, Total Reward: 19.04, Loss: 47.1717, Crashes: 10, Crash Reward: -2.00, Time: 14.42s
# Episode 20, Total Reward: 64.13, Loss: 79.1364, Crashes: 45, Crash Reward: -9.00, Time: 35.35s
# Episode 21, Total Reward: 1.92, Loss: 15.7839, Crashes: 8, Crash Reward: -1.60, Time: 5.75s
# Episode 22, Total Reward: 2.38, Loss: 0.1121, Crashes: 6, Crash Reward: -1.20, Time: 4.54s
# Episode 23, Total Reward: 0.81, Loss: 15.6777, Crashes: 6, Crash Reward: -1.20, Time: 4.38s
# Episode 24, Total Reward: 11.19, Loss: 47.0008, Crashes: 7, Crash Reward: -1.40, Time: 11.36s
# Episode 25, Total Reward: 575.20, Loss: 78.5182, Crashes: 47, Crash Reward: -9.40, Time: 33.33s
# Episode 26, Total Reward: 0.00, Loss: 0.0644, Crashes: 0, Crash Reward: 0.00, Time: 4.33s
# Episode 27, Total Reward: 2.21, Loss: 0.0619, Crashes: 4, Crash Reward: -0.80, Time: 4.42s
# Episode 28, Total Reward: 2.49, Loss: 0.0711, Crashes: 8, Crash Reward: -1.60, Time: 4.77s
# Episode 29, Total Reward: 2.28, Loss: 15.6538, Crashes: 6, Crash Reward: -1.20, Time: 4.63s
# Episode 30, Total Reward: 18.43, Loss: 47.0633, Crashes: 15, Crash Reward: -3.00, Time: 18.87s
# Episode 31, Total Reward: 17.91, Loss: 47.2144, Crashes: 17, Crash Reward: -3.40, Time: 16.24s
# Episode 32, Total Reward: 2.40, Loss: 15.7001, Crashes: 5, Crash Reward: -1.00, Time: 5.63s
# Episode 33, Total Reward: -0.80, Loss: 31.2367, Crashes: 4, Crash Reward: -0.80, Time: 4.32s
# Episode 34, Total Reward: 2.47, Loss: 0.1201, Crashes: 7, Crash Reward: -1.40, Time: 6.33s
# Episode 35, Total Reward: -0.80, Loss: 0.0836, Crashes: 4, Crash Reward: -0.80, Time: 4.32s
# Episode 36, Total Reward: 18.13, Loss: 15.7947, Crashes: 17, Crash Reward: -3.40, Time: 11.78s
# Episode 37, Total Reward: -0.80, Loss: 0.0661, Crashes: 4, Crash Reward: -0.80, Time: 4.34s
# Episode 38, Total Reward: 3.62, Loss: 0.1056, Crashes: 6, Crash Reward: -1.20, Time: 6.03s
# Episode 39, Total Reward: 1.24, Loss: 15.6529, Crashes: 4, Crash Reward: -0.80, Time: 4.34s
# Episode 40, Total Reward: 6.44, Loss: 15.6933, Crashes: 5, Crash Reward: -1.00, Time: 6.63s
# Episode 41, Total Reward: -0.80, Loss: 0.1770, Crashes: 4, Crash Reward: -0.80, Time: 4.48s
# Episode 42, Total Reward: -0.80, Loss: 46.5286, Crashes: 4, Crash Reward: -0.80, Time: 4.33s
# Episode 43, Total Reward: 0.98, Loss: 0.3878, Crashes: 7, Crash Reward: -1.40, Time: 4.34s
# Episode 44, Total Reward: 3.34, Loss: 0.4066, Crashes: 7, Crash Reward: -1.40, Time: 5.74s
# Episode 45, Total Reward: 2.89, Loss: 0.2535, Crashes: 4, Crash Reward: -0.80, Time: 4.83s
# Episode 46, Total Reward: -0.80, Loss: 0.1898, Crashes: 4, Crash Reward: -0.80, Time: 4.32s
# Episode 47, Total Reward: 1.46, Loss: 15.7850, Crashes: 6, Crash Reward: -1.20, Time: 4.83s
# Episode 48, Total Reward: 2.48, Loss: 15.7789, Crashes: 3, Crash Reward: -0.60, Time: 4.32s
# Episode 49, Total Reward: 2.11, Loss: 15.7566, Crashes: 4, Crash Reward: -0.80, Time: 4.34s
# Episode 50, Total Reward: 4.59, Loss: 0.3646, Crashes: 8, Crash Reward: -1.60, Time: 6.07s
# Episode 51, Total Reward: 19.20, Loss: 16.3801, Crashes: 15, Crash Reward: -3.00, Time: 11.28s
# Episode 52, Total Reward: -0.80, Loss: 15.7230, Crashes: 4, Crash Reward: -0.80, Time: 4.32s
# Episode 53, Total Reward: 1.79, Loss: 0.1414, Crashes: 4, Crash Reward: -0.80, Time: 4.33s
# Episode 54, Total Reward: 1.60, Loss: 0.1441, Crashes: 7, Crash Reward: -1.40, Time: 4.48s
# Episode 55, Total Reward: -0.80, Loss: 0.4534, Crashes: 4, Crash Reward: -0.80, Time: 4.34s
# Episode 56, Total Reward: 17.74, Loss: 31.9036, Crashes: 18, Crash Reward: -3.60, Time: 14.98s
# Episode 57, Total Reward: 1.95, Loss: 0.1291, Crashes: 6, Crash Reward: -1.20, Time: 4.94s
# Episode 58, Total Reward: 2.10, Loss: 0.1672, Crashes: 6, Crash Reward: -1.20, Time: 5.50s
# Episode 59, Total Reward: -1.00, Loss: 31.5781, Crashes: 5, Crash Reward: -1.00, Time: 4.34s
# Episode 60, Total Reward: 0.91, Loss: 16.0068, Crashes: 5, Crash Reward: -1.00, Time: 4.33s
# Episode 61, Total Reward: 0.62, Loss: 0.1804, Crashes: 6, Crash Reward: -1.20, Time: 4.33s
# Episode 62, Total Reward: 1.12, Loss: 0.8171, Crashes: 3, Crash Reward: -0.60, Time: 4.48s
# Episode 63, Total Reward: 2.75, Loss: 0.1779, Crashes: 6, Crash Reward: -1.20, Time: 4.68s
# Episode 64, Total Reward: 8.45, Loss: 0.9456, Crashes: 6, Crash Reward: -1.20, Time: 7.58s
# Episode 65, Total Reward: 5.44, Loss: 1.0658, Crashes: 9, Crash Reward: -1.80, Time: 7.33s
# Episode 66, Total Reward: 1.78, Loss: 0.1882, Crashes: 7, Crash Reward: -1.40, Time: 5.43s
# Episode 67, Total Reward: 2.36, Loss: 15.9249, Crashes: 8, Crash Reward: -1.60, Time: 6.27s
# Episode 68, Total Reward: 19.30, Loss: 1.6090, Crashes: 21, Crash Reward: -4.20, Time: 13.18s
# Episode 69, Total Reward: 16.82, Loss: 31.7339, Crashes: 24, Crash Reward: -4.80, Time: 16.41s
# Episode 70, Total Reward: 2.01, Loss: 0.1447, Crashes: 5, Crash Reward: -1.00, Time: 5.33s
# Episode 71, Total Reward: 5.00, Loss: 15.8067, Crashes: 12, Crash Reward: -2.40, Time: 9.18s
# Episode 72, Total Reward: 1.36, Loss: 0.4834, Crashes: 7, Crash Reward: -1.40, Time: 4.39s
# Episode 73, Total Reward: 1.85, Loss: 0.2208, Crashes: 7, Crash Reward: -1.40, Time: 4.52s
# Episode 74, Total Reward: 2.72, Loss: 0.2730, Crashes: 8, Crash Reward: -1.60, Time: 5.83s
# Episode 75, Total Reward: 18.23, Loss: 34.9116, Crashes: 16, Crash Reward: -3.20, Time: 12.67s
# Episode 76, Total Reward: 18.18, Loss: 33.0010, Crashes: 14, Crash Reward: -2.80, Time: 16.05s
# Episode 77, Total Reward: 4.85, Loss: 0.5433, Crashes: 5, Crash Reward: -1.00, Time: 6.18s
# Episode 78, Total Reward: -1.00, Loss: 0.3342, Crashes: 5, Crash Reward: -1.00, Time: 4.32s
# Episode 79, Total Reward: 46.64, Loss: 17.6162, Crashes: 35, Crash Reward: -7.00, Time: 28.94s
# Episode 80, Total Reward: 2.52, Loss: 0.1967, Crashes: 5, Crash Reward: -1.00, Time: 4.48s
# Episode 81, Total Reward: 1.13, Loss: 0.2419, Crashes: 5, Crash Reward: -1.00, Time: 4.34s
# Episode 82, Total Reward: 1.28, Loss: 0.2400, Crashes: 6, Crash Reward: -1.20, Time: 4.34s
# Episode 83, Total Reward: 1.92, Loss: 0.2269, Crashes: 2, Crash Reward: -0.40, Time: 4.34s
# Episode 84, Total Reward: 4.45, Loss: 0.3686, Crashes: 6, Crash Reward: -1.20, Time: 7.13s
# Episode 85, Total Reward: 2.35, Loss: 0.2508, Crashes: 7, Crash Reward: -1.40, Time: 5.78s
# Episode 86, Total Reward: 2.19, Loss: 15.8387, Crashes: 9, Crash Reward: -1.80, Time: 6.38s
# Episode 87, Total Reward: 18.55, Loss: 63.8812, Crashes: 16, Crash Reward: -3.20, Time: 15.34s
# Episode 88, Total Reward: 47.79, Loss: 38.8932, Crashes: 30, Crash Reward: -6.00, Time: 21.60s
# Episode 89, Total Reward: 1.09, Loss: 0.6179, Crashes: 5, Crash Reward: -1.00, Time: 4.52s
# Episode 90, Total Reward: 0.84, Loss: 0.5767, Crashes: 7, Crash Reward: -1.40, Time: 4.32s
# Episode 91, Total Reward: 9.67, Loss: 6.7315, Crashes: 10, Crash Reward: -2.00, Time: 7.78s
# Episode 92, Total Reward: 18.17, Loss: 34.6496, Crashes: 15, Crash Reward: -3.00, Time: 14.68s
# Episode 93, Total Reward: 1.96, Loss: 0.5820, Crashes: 7, Crash Reward: -1.40, Time: 4.57s
# Episode 94, Total Reward: 21.69, Loss: 1.4382, Crashes: 8, Crash Reward: -1.60, Time: 11.19s
# Episode 95, Total Reward: 43.46, Loss: 34.5117, Crashes: 45, Crash Reward: -9.00, Time: 26.06s
# Episode 96, Total Reward: 1.30, Loss: 1.2606, Crashes: 4, Crash Reward: -0.80, Time: 4.41s
# Episode 97, Total Reward: 576.20, Loss: 91.9545, Crashes: 42, Crash Reward: -8.40, Time: 32.77s
# Episode 98, Total Reward: 18.13, Loss: 18.5396, Crashes: 13, Crash Reward: -2.60, Time: 16.63s
# Router model saved at episode 100
# Episode 99, Total Reward: 2.37, Loss: 6.8351, Crashes: 7, Crash Reward: -1.40, Time: 5.18s
# Episode 100, Total Reward: -1.00, Loss: 16.1128, Crashes: 5, Crash Reward: -1.00, Time: 4.33s
# Episode 101, Total Reward: 1.73, Loss: 0.5688, Crashes: 9, Crash Reward: -1.80, Time: 5.73s
# Episode 102, Total Reward: 1.30, Loss: 15.9590, Crashes: 7, Crash Reward: -1.40, Time: 4.33s
# Episode 103, Total Reward: 2.03, Loss: 15.9792, Crashes: 3, Crash Reward: -0.60, Time: 4.41s
# Episode 104, Total Reward: 75.20, Loss: 96.9915, Crashes: 47, Crash Reward: -9.40, Time: 40.48s
# Episode 105, Total Reward: 19.44, Loss: 32.1131, Crashes: 20, Crash Reward: -4.00, Time: 12.69s
# Episode 106, Total Reward: 19.30, Loss: 1.0416, Crashes: 22, Crash Reward: -4.40, Time: 12.49s
# Episode 107, Total Reward: 2.56, Loss: 15.8545, Crashes: 6, Crash Reward: -1.20, Time: 4.67s
# Episode 108, Total Reward: 17.98, Loss: 32.0868, Crashes: 15, Crash Reward: -3.00, Time: 13.11s
# Episode 109, Total Reward: 5.81, Loss: 0.5512, Crashes: 10, Crash Reward: -2.00, Time: 8.02s
# Episode 110, Total Reward: 4.77, Loss: 16.0326, Crashes: 10, Crash Reward: -2.00, Time: 7.10s
# Episode 111, Total Reward: -0.80, Loss: 0.3870, Crashes: 4, Crash Reward: -0.80, Time: 4.55s
# Episode 112, Total Reward: 1.52, Loss: 15.9304, Crashes: 7, Crash Reward: -1.40, Time: 4.60s
# Episode 113, Total Reward: 1.72, Loss: 15.8799, Crashes: 5, Crash Reward: -1.00, Time: 4.34s
# Episode 114, Total Reward: 48.68, Loss: 17.6421, Crashes: 22, Crash Reward: -4.40, Time: 23.39s
# Episode 115, Total Reward: 6.49, Loss: 0.5833, Crashes: 8, Crash Reward: -1.60, Time: 7.38s
# Episode 116, Total Reward: 20.86, Loss: 16.9876, Crashes: 10, Crash Reward: -2.00, Time: 17.28s
# Episode 117, Total Reward: 50.28, Loss: 33.8350, Crashes: 27, Crash Reward: -5.40, Time: 34.53s
# Episode 118, Total Reward: 15.44, Loss: 47.5058, Crashes: 13, Crash Reward: -2.60, Time: 11.51s
# Episode 119, Total Reward: 1.67, Loss: 15.8249, Crashes: 5, Crash Reward: -1.00, Time: 4.54s
# Episode 120, Total Reward: 2.01, Loss: 31.4274, Crashes: 6, Crash Reward: -1.20, Time: 4.80s
# Episode 121, Total Reward: 1.08, Loss: 0.3968, Crashes: 6, Crash Reward: -1.20, Time: 4.34s
# Episode 122, Total Reward: 18.14, Loss: 1.6691, Crashes: 16, Crash Reward: -3.20, Time: 16.74s
# Episode 123, Total Reward: 1.93, Loss: 0.3611, Crashes: 4, Crash Reward: -0.80, Time: 4.47s
# Episode 124, Total Reward: 1.23, Loss: 0.3147, Crashes: 7, Crash Reward: -1.40, Time: 4.53s
# Episode 125, Total Reward: 19.22, Loss: 1.0296, Crashes: 12, Crash Reward: -2.40, Time: 12.09s
# Episode 126, Total Reward: 2.35, Loss: 15.9874, Crashes: 6, Crash Reward: -1.20, Time: 5.63s
# Episode 127, Total Reward: 579.00, Loss: 96.7369, Crashes: 28, Crash Reward: -5.60, Time: 42.67s
# Episode 128, Total Reward: 1.35, Loss: 0.3810, Crashes: 9, Crash Reward: -1.80, Time: 5.90s
# Episode 129, Total Reward: 17.19, Loss: 32.5055, Crashes: 18, Crash Reward: -3.60, Time: 18.89s
# Episode 130, Total Reward: 3.61, Loss: 0.2971, Crashes: 5, Crash Reward: -1.00, Time: 4.88s
# Episode 131, Total Reward: 1.85, Loss: 0.7035, Crashes: 8, Crash Reward: -1.60, Time: 6.51s
# Episode 132, Total Reward: 3.58, Loss: 16.2940, Crashes: 10, Crash Reward: -2.00, Time: 6.83s
# Episode 133, Total Reward: 4.93, Loss: 0.6018, Crashes: 8, Crash Reward: -1.60, Time: 6.48s
# Episode 134, Total Reward: 4.62, Loss: 16.1721, Crashes: 6, Crash Reward: -1.20, Time: 7.18s
# Episode 135, Total Reward: 2.34, Loss: 0.4541, Crashes: 5, Crash Reward: -1.00, Time: 5.33s
# Episode 136, Total Reward: 6.12, Loss: 47.3463, Crashes: 10, Crash Reward: -2.00, Time: 8.29s
# Episode 137, Total Reward: 2.56, Loss: 15.8619, Crashes: 4, Crash Reward: -0.80, Time: 4.49s
# Episode 138, Total Reward: 2.51, Loss: 47.1182, Crashes: 8, Crash Reward: -1.60, Time: 6.21s
# Episode 139, Total Reward: -0.80, Loss: 15.9192, Crashes: 4, Crash Reward: -0.80, Time: 4.54s
# Episode 140, Total Reward: 51.11, Loss: 49.4108, Crashes: 27, Crash Reward: -5.40, Time: 32.54s
# Episode 141, Total Reward: 19.40, Loss: 17.9139, Crashes: 13, Crash Reward: -2.60, Time: 19.85s
# Episode 142, Total Reward: 1.60, Loss: 15.9657, Crashes: 4, Crash Reward: -0.80, Time: 4.50s
# Episode 143, Total Reward: 18.51, Loss: 17.3238, Crashes: 14, Crash Reward: -2.80, Time: 16.93s
# Episode 144, Total Reward: 1.95, Loss: 0.5138, Crashes: 6, Crash Reward: -1.20, Time: 5.32s
# Episode 145, Total Reward: 20.10, Loss: 17.0521, Crashes: 16, Crash Reward: -3.20, Time: 16.21s
# Episode 146, Total Reward: 75.89, Loss: 58.6820, Crashes: 32, Crash Reward: -6.40, Time: 47.47s
# Episode 147, Total Reward: 2.19, Loss: 0.7987, Crashes: 4, Crash Reward: -0.80, Time: 4.54s
# Episode 148, Total Reward: 2.52, Loss: 0.9208, Crashes: 9, Crash Reward: -1.80, Time: 5.98s
# Episode 149, Total Reward: 16.81, Loss: 2.3385, Crashes: 24, Crash Reward: -4.80, Time: 17.73s
# Episode 150, Total Reward: 578.40, Loss: 67.1247, Crashes: 31, Crash Reward: -6.20, Time: 45.15s
# Episode 151, Total Reward: 18.65, Loss: 22.2770, Crashes: 13, Crash Reward: -2.60, Time: 18.28s
# Episode 152, Total Reward: 3.96, Loss: 0.4875, Crashes: 8, Crash Reward: -1.60, Time: 5.29s
# Episode 153, Total Reward: 2.92, Loss: 0.5351, Crashes: 7, Crash Reward: -1.40, Time: 6.07s
# Episode 154, Total Reward: 18.36, Loss: 17.0605, Crashes: 16, Crash Reward: -3.20, Time: 19.38s
# Episode 155, Total Reward: 19.46, Loss: 3.5210, Crashes: 15, Crash Reward: -3.00, Time: 15.05s
# Episode 156, Total Reward: 18.93, Loss: 19.9209, Crashes: 16, Crash Reward: -3.20, Time: 15.61s
# Episode 157, Total Reward: 6.90, Loss: 1.5713, Crashes: 4, Crash Reward: -0.80, Time: 6.11s
# Episode 158, Total Reward: 57.92, Loss: 50.3363, Crashes: 40, Crash Reward: -8.00, Time: 29.78s
# Episode 159, Total Reward: 2.71, Loss: 38.6973, Crashes: 6, Crash Reward: -1.20, Time: 5.43s
# Episode 160, Total Reward: 4.88, Loss: 35.3712, Crashes: 14, Crash Reward: -2.80, Time: 9.29s
# Episode 161, Total Reward: 573.80, Loss: 170.3479, Crashes: 54, Crash Reward: -10.80, Time: 39.55s
# Episode 162, Total Reward: 18.27, Loss: 33.5155, Crashes: 13, Crash Reward: -2.60, Time: 12.09s
# Episode 163, Total Reward: 20.97, Loss: 90.4365, Crashes: 18, Crash Reward: -3.60, Time: 21.90s
# Episode 164, Total Reward: 18.37, Loss: 85.1512, Crashes: 11, Crash Reward: -2.20, Time: 14.27s
# Episode 165, Total Reward: 2.44, Loss: 10.4712, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 166, Total Reward: 23.84, Loss: 73.2859, Crashes: 13, Crash Reward: -2.60, Time: 16.88s
# Episode 167, Total Reward: 57.25, Loss: 58.5245, Crashes: 32, Crash Reward: -6.40, Time: 37.00s
# Episode 168, Total Reward: 5.21, Loss: 11.7017, Crashes: 7, Crash Reward: -1.40, Time: 8.48s
# Episode 169, Total Reward: 65.94, Loss: 133.6790, Crashes: 57, Crash Reward: -11.40, Time: 32.70s
# Episode 170, Total Reward: 77.80, Loss: 157.3081, Crashes: 34, Crash Reward: -6.80, Time: 41.43s
# Episode 171, Total Reward: 76.80, Loss: 40.4602, Crashes: 39, Crash Reward: -7.80, Time: 36.99s
# Episode 172, Total Reward: 3.01, Loss: 3.1261, Crashes: 8, Crash Reward: -1.60, Time: 6.06s
# Episode 173, Total Reward: 2.08, Loss: 1.3021, Crashes: 3, Crash Reward: -0.60, Time: 4.53s
# Episode 174, Total Reward: 5.16, Loss: 1.4552, Crashes: 3, Crash Reward: -0.60, Time: 7.58s
# Episode 175, Total Reward: 51.79, Loss: 64.3959, Crashes: 30, Crash Reward: -6.00, Time: 36.76s
# Episode 176, Total Reward: 47.99, Loss: 59.3506, Crashes: 23, Crash Reward: -4.60, Time: 25.10s
# Episode 177, Total Reward: 0.85, Loss: 4.5314, Crashes: 5, Crash Reward: -1.00, Time: 4.34s
# Episode 178, Total Reward: 23.46, Loss: 27.6047, Crashes: 15, Crash Reward: -3.00, Time: 20.74s
# Episode 179, Total Reward: 46.82, Loss: 37.8427, Crashes: 30, Crash Reward: -6.00, Time: 25.51s
# Episode 180, Total Reward: 5.65, Loss: 18.3715, Crashes: 9, Crash Reward: -1.80, Time: 7.54s
# Episode 181, Total Reward: 5.69, Loss: 4.6879, Crashes: 8, Crash Reward: -1.60, Time: 6.20s
# Episode 182, Total Reward: 1.49, Loss: 1.7050, Crashes: 4, Crash Reward: -0.80, Time: 4.55s
# Episode 183, Total Reward: 19.86, Loss: 22.1979, Crashes: 13, Crash Reward: -2.60, Time: 20.54s
# Episode 184, Total Reward: 3.15, Loss: 1.0290, Crashes: 7, Crash Reward: -1.40, Time: 6.63s
# Episode 185, Total Reward: 3.33, Loss: 23.3700, Crashes: 7, Crash Reward: -1.40, Time: 6.08s
# Episode 186, Total Reward: 61.62, Loss: 81.5696, Crashes: 21, Crash Reward: -4.20, Time: 34.64s
# Episode 187, Total Reward: 5.84, Loss: 16.9660, Crashes: 9, Crash Reward: -1.80, Time: 6.43s
# Episode 188, Total Reward: -0.60, Loss: 1.4762, Crashes: 3, Crash Reward: -0.60, Time: 4.37s
# Episode 189, Total Reward: 2.60, Loss: 17.0059, Crashes: 3, Crash Reward: -0.60, Time: 4.49s
# Episode 190, Total Reward: 8.63, Loss: 18.0088, Crashes: 9, Crash Reward: -1.80, Time: 7.69s
# Episode 191, Total Reward: 6.24, Loss: 1.7121, Crashes: 11, Crash Reward: -2.20, Time: 8.52s
# Episode 192, Total Reward: 3.39, Loss: 27.1823, Crashes: 5, Crash Reward: -1.00, Time: 4.73s
# Episode 193, Total Reward: 18.63, Loss: 40.1110, Crashes: 18, Crash Reward: -3.60, Time: 19.22s
# Episode 194, Total Reward: 77.00, Loss: 90.8023, Crashes: 38, Crash Reward: -7.60, Time: 48.95s
# Episode 195, Total Reward: 18.17, Loss: 35.6564, Crashes: 18, Crash Reward: -3.60, Time: 14.62s
# Episode 196, Total Reward: 1.79, Loss: 1.0154, Crashes: 3, Crash Reward: -0.60, Time: 4.47s
# Episode 197, Total Reward: 2.70, Loss: 18.8402, Crashes: 5, Crash Reward: -1.00, Time: 4.76s
# Episode 198, Total Reward: 6.07, Loss: 2.9517, Crashes: 5, Crash Reward: -1.00, Time: 6.18s
# Router model saved at episode 200
# Episode 199, Total Reward: 2.91, Loss: 1.3146, Crashes: 5, Crash Reward: -1.00, Time: 5.60s
# Episode 200, Total Reward: 8.10, Loss: 1.4388, Crashes: 7, Crash Reward: -1.40, Time: 6.89s
# Episode 201, Total Reward: 47.79, Loss: 16.0573, Crashes: 32, Crash Reward: -6.40, Time: 31.24s
# Episode 202, Total Reward: 16.53, Loss: 15.6378, Crashes: 18, Crash Reward: -3.60, Time: 13.34s
# Episode 203, Total Reward: 81.00, Loss: 60.3725, Crashes: 18, Crash Reward: -3.60, Time: 46.10s
# Episode 204, Total Reward: 76.40, Loss: 99.0829, Crashes: 41, Crash Reward: -8.20, Time: 51.81s
# Episode 205, Total Reward: 2.81, Loss: 4.1912, Crashes: 3, Crash Reward: -0.60, Time: 4.54s
# Episode 206, Total Reward: 6.16, Loss: 17.3973, Crashes: 3, Crash Reward: -0.60, Time: 6.21s
# Episode 207, Total Reward: 22.22, Loss: 4.1969, Crashes: 10, Crash Reward: -2.00, Time: 16.99s
# Episode 208, Total Reward: 78.00, Loss: 82.3482, Crashes: 33, Crash Reward: -6.60, Time: 41.69s
# Episode 209, Total Reward: 579.40, Loss: 88.8507, Crashes: 26, Crash Reward: -5.20, Time: 46.59s
# Episode 210, Total Reward: 76.60, Loss: 120.5118, Crashes: 40, Crash Reward: -8.00, Time: 45.94s
# Episode 211, Total Reward: 76.20, Loss: 85.5651, Crashes: 42, Crash Reward: -8.40, Time: 44.39s
# Episode 212, Total Reward: 57.26, Loss: 34.7001, Crashes: 33, Crash Reward: -6.60, Time: 27.41s
# Episode 213, Total Reward: 77.00, Loss: 42.9795, Crashes: 38, Crash Reward: -7.60, Time: 46.26s
# Episode 214, Total Reward: 18.98, Loss: 34.2469, Crashes: 14, Crash Reward: -2.80, Time: 12.92s
# Episode 215, Total Reward: 577.00, Loss: 22.7879, Crashes: 38, Crash Reward: -7.60, Time: 34.17s
# Episode 216, Total Reward: 5.05, Loss: 1.4380, Crashes: 10, Crash Reward: -2.00, Time: 7.79s
# Episode 217, Total Reward: 4.29, Loss: 0.9022, Crashes: 6, Crash Reward: -1.20, Time: 5.95s
# Episode 218, Total Reward: 77.00, Loss: 83.6297, Crashes: 38, Crash Reward: -7.60, Time: 43.06s
# Episode 219, Total Reward: 5.42, Loss: 17.1263, Crashes: 7, Crash Reward: -1.40, Time: 7.63s
# Episode 220, Total Reward: 21.09, Loss: 1.7598, Crashes: 15, Crash Reward: -3.00, Time: 11.45s
# Episode 221, Total Reward: 3.87, Loss: 0.7862, Crashes: 6, Crash Reward: -1.20, Time: 4.69s
# Episode 222, Total Reward: 70.54, Loss: 21.8101, Crashes: 35, Crash Reward: -7.00, Time: 35.58s
# Episode 223, Total Reward: 21.61, Loss: 17.7159, Crashes: 15, Crash Reward: -3.00, Time: 13.01s
# Episode 224, Total Reward: 78.40, Loss: 68.8181, Crashes: 31, Crash Reward: -6.20, Time: 44.24s
# Episode 225, Total Reward: -0.80, Loss: 0.6251, Crashes: 4, Crash Reward: -0.80, Time: 4.52s
# Episode 226, Total Reward: 48.40, Loss: 35.6938, Crashes: 25, Crash Reward: -5.00, Time: 31.81s
# Episode 227, Total Reward: 6.72, Loss: 16.4186, Crashes: 12, Crash Reward: -2.40, Time: 7.03s
# Episode 228, Total Reward: 2.53, Loss: 0.4790, Crashes: 8, Crash Reward: -1.60, Time: 4.54s
# Episode 229, Total Reward: 5.94, Loss: 16.3966, Crashes: 6, Crash Reward: -1.20, Time: 7.09s
# Episode 230, Total Reward: 79.80, Loss: 84.0671, Crashes: 24, Crash Reward: -4.80, Time: 46.63s
# Episode 231, Total Reward: 22.50, Loss: 34.5739, Crashes: 18, Crash Reward: -3.60, Time: 18.00s
# Episode 232, Total Reward: 577.80, Loss: 37.4587, Crashes: 34, Crash Reward: -6.80, Time: 35.09s
# Episode 233, Total Reward: -0.80, Loss: 0.5515, Crashes: 4, Crash Reward: -0.80, Time: 4.51s
# Episode 234, Total Reward: 576.80, Loss: 83.3834, Crashes: 39, Crash Reward: -7.80, Time: 36.23s
# Episode 235, Total Reward: 6.25, Loss: 16.6070, Crashes: 11, Crash Reward: -2.20, Time: 7.22s
# Episode 236, Total Reward: 49.37, Loss: 4.6330, Crashes: 32, Crash Reward: -6.40, Time: 32.40s
# Episode 237, Total Reward: 4.80, Loss: 16.5729, Crashes: 8, Crash Reward: -1.60, Time: 5.58s
# Episode 238, Total Reward: 18.31, Loss: 2.6763, Crashes: 13, Crash Reward: -2.60, Time: 19.45s
# Episode 239, Total Reward: 2.50, Loss: 16.0990, Crashes: 6, Crash Reward: -1.20, Time: 4.99s
# Episode 240, Total Reward: 32.85, Loss: 49.4469, Crashes: 28, Crash Reward: -5.60, Time: 22.23s
# Episode 241, Total Reward: 20.81, Loss: 96.9312, Crashes: 16, Crash Reward: -3.20, Time: 18.31s
# Episode 242, Total Reward: 6.79, Loss: 7.7155, Crashes: 10, Crash Reward: -2.00, Time: 8.12s
# Episode 243, Total Reward: 78.60, Loss: 93.2383, Crashes: 30, Crash Reward: -6.00, Time: 52.17s
# Episode 244, Total Reward: 49.39, Loss: 19.6081, Crashes: 30, Crash Reward: -6.00, Time: 26.08s
# Episode 245, Total Reward: 24.70, Loss: 3.7806, Crashes: 30, Crash Reward: -6.00, Time: 23.95s
# Episode 246, Total Reward: 76.80, Loss: 112.4838, Crashes: 39, Crash Reward: -7.80, Time: 36.15s
# Episode 247, Total Reward: 2.78, Loss: 1.8090, Crashes: 4, Crash Reward: -0.80, Time: 4.33s
# Episode 248, Total Reward: -0.80, Loss: 1.5413, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 249, Total Reward: 25.65, Loss: 60.6752, Crashes: 18, Crash Reward: -3.60, Time: 16.80s
# Episode 250, Total Reward: 6.57, Loss: 3.3870, Crashes: 2, Crash Reward: -0.40, Time: 5.81s
# Episode 251, Total Reward: 17.33, Loss: 32.8722, Crashes: 16, Crash Reward: -3.20, Time: 13.83s
# Episode 252, Total Reward: -0.60, Loss: 19.4852, Crashes: 3, Crash Reward: -0.60, Time: 4.54s
# Episode 253, Total Reward: 1.20, Loss: 33.8797, Crashes: 7, Crash Reward: -1.40, Time: 4.73s
# Episode 254, Total Reward: 24.05, Loss: 26.4281, Crashes: 27, Crash Reward: -5.40, Time: 20.59s
# Episode 255, Total Reward: -0.80, Loss: 1.6501, Crashes: 4, Crash Reward: -0.80, Time: 4.34s
# Episode 256, Total Reward: 5.68, Loss: 33.4054, Crashes: 13, Crash Reward: -2.60, Time: 6.18s
# Episode 257, Total Reward: 21.57, Loss: 57.7367, Crashes: 9, Crash Reward: -1.80, Time: 18.90s
# Episode 258, Total Reward: 21.32, Loss: 52.2126, Crashes: 16, Crash Reward: -3.20, Time: 18.80s
# Episode 259, Total Reward: 2.45, Loss: 1.4391, Crashes: 9, Crash Reward: -1.80, Time: 5.58s
# Episode 260, Total Reward: 5.35, Loss: 58.8811, Crashes: 10, Crash Reward: -2.00, Time: 7.23s
# Episode 261, Total Reward: 3.55, Loss: 1.1713, Crashes: 6, Crash Reward: -1.20, Time: 4.59s
# Episode 262, Total Reward: 9.68, Loss: 48.7540, Crashes: 11, Crash Reward: -2.20, Time: 7.84s
# Episode 263, Total Reward: 76.20, Loss: 89.5503, Crashes: 42, Crash Reward: -8.40, Time: 47.27s
# Episode 264, Total Reward: -0.80, Loss: 0.8887, Crashes: 4, Crash Reward: -0.80, Time: 4.54s
# Episode 265, Total Reward: 10.91, Loss: 2.2783, Crashes: 16, Crash Reward: -3.20, Time: 10.19s
# Episode 266, Total Reward: 575.80, Loss: 23.4846, Crashes: 44, Crash Reward: -8.80, Time: 33.80s
# Episode 267, Total Reward: 50.74, Loss: 116.0974, Crashes: 24, Crash Reward: -4.80, Time: 33.90s
# Episode 268, Total Reward: 75.71, Loss: 40.6825, Crashes: 36, Crash Reward: -7.20, Time: 45.10s
# Episode 269, Total Reward: 4.54, Loss: 1.2879, Crashes: 11, Crash Reward: -2.20, Time: 6.78s
# Episode 270, Total Reward: 78.00, Loss: 55.8511, Crashes: 33, Crash Reward: -6.60, Time: 44.14s
# Episode 271, Total Reward: 2.44, Loss: 1.1452, Crashes: 6, Crash Reward: -1.20, Time: 4.98s
# Episode 272, Total Reward: 578.40, Loss: 85.4553, Crashes: 31, Crash Reward: -6.20, Time: 44.36s
# Episode 273, Total Reward: 20.57, Loss: 4.9680, Crashes: 12, Crash Reward: -2.40, Time: 15.46s
# Episode 274, Total Reward: 1.88, Loss: 8.5687, Crashes: 6, Crash Reward: -1.20, Time: 4.58s
# Episode 275, Total Reward: 24.11, Loss: 55.6625, Crashes: 19, Crash Reward: -3.80, Time: 19.55s
# Episode 276, Total Reward: 1.50, Loss: 1.4491, Crashes: 4, Crash Reward: -0.80, Time: 4.51s
# Episode 277, Total Reward: 18.11, Loss: 67.3268, Crashes: 14, Crash Reward: -2.80, Time: 15.50s
# Episode 278, Total Reward: 18.95, Loss: 21.9078, Crashes: 15, Crash Reward: -3.00, Time: 19.72s
# Episode 279, Total Reward: 77.80, Loss: 42.6646, Crashes: 34, Crash Reward: -6.80, Time: 39.01s
# Episode 280, Total Reward: 574.80, Loss: 63.6402, Crashes: 49, Crash Reward: -9.80, Time: 30.36s
# Episode 281, Total Reward: 4.11, Loss: 2.9622, Crashes: 8, Crash Reward: -1.60, Time: 6.66s
# Episode 282, Total Reward: 578.35, Loss: 188.7566, Crashes: 30, Crash Reward: -6.00, Time: 48.96s
# Episode 283, Total Reward: 3.38, Loss: 16.7032, Crashes: 7, Crash Reward: -1.40, Time: 4.74s
# Episode 284, Total Reward: 17.77, Loss: 34.9211, Crashes: 16, Crash Reward: -3.20, Time: 12.24s
# Episode 285, Total Reward: 576.80, Loss: 106.0023, Crashes: 39, Crash Reward: -7.80, Time: 40.71s
# Episode 286, Total Reward: 8.82, Loss: 18.0475, Crashes: 10, Crash Reward: -2.00, Time: 8.94s
# Episode 287, Total Reward: 76.60, Loss: 89.6617, Crashes: 40, Crash Reward: -8.00, Time: 38.90s
# Episode 288, Total Reward: 7.37, Loss: 2.1162, Crashes: 4, Crash Reward: -0.80, Time: 7.69s
# Episode 289, Total Reward: 5.37, Loss: 2.1949, Crashes: 9, Crash Reward: -1.80, Time: 7.52s
# Episode 290, Total Reward: 46.76, Loss: 136.5228, Crashes: 36, Crash Reward: -7.20, Time: 30.37s
# Episode 291, Total Reward: 3.88, Loss: 17.0991, Crashes: 5, Crash Reward: -1.00, Time: 5.03s
# Episode 292, Total Reward: 52.17, Loss: 54.8555, Crashes: 25, Crash Reward: -5.00, Time: 33.52s
# Episode 293, Total Reward: 5.22, Loss: 32.7616, Crashes: 6, Crash Reward: -1.20, Time: 7.71s
# Episode 294, Total Reward: 2.20, Loss: 16.6801, Crashes: 8, Crash Reward: -1.60, Time: 5.64s
# Episode 295, Total Reward: 1.90, Loss: 0.7946, Crashes: 6, Crash Reward: -1.20, Time: 4.53s
# Episode 296, Total Reward: 2.59, Loss: 16.3279, Crashes: 7, Crash Reward: -1.40, Time: 4.53s
# Episode 297, Total Reward: 78.80, Loss: 102.9719, Crashes: 29, Crash Reward: -5.80, Time: 43.73s
# Episode 298, Total Reward: 78.40, Loss: 157.5148, Crashes: 31, Crash Reward: -6.20, Time: 47.30s
# Router model saved at episode 300
# Episode 299, Total Reward: 78.80, Loss: 30.5373, Crashes: 29, Crash Reward: -5.80, Time: 40.50s
# Episode 300, Total Reward: 75.60, Loss: 62.2013, Crashes: 45, Crash Reward: -9.00, Time: 42.37s
# Episode 301, Total Reward: 6.32, Loss: 1.9201, Crashes: 6, Crash Reward: -1.20, Time: 7.53s
# Episode 302, Total Reward: 6.91, Loss: 6.1615, Crashes: 10, Crash Reward: -2.00, Time: 7.04s
# Episode 303, Total Reward: 5.85, Loss: 1.3513, Crashes: 7, Crash Reward: -1.40, Time: 7.07s
# Episode 304, Total Reward: 20.16, Loss: 49.0141, Crashes: 18, Crash Reward: -3.60, Time: 16.52s
# Episode 305, Total Reward: 76.20, Loss: 117.7387, Crashes: 42, Crash Reward: -8.40, Time: 41.77s
# Episode 306, Total Reward: 0.83, Loss: 11.4715, Crashes: 5, Crash Reward: -1.00, Time: 4.50s
# Episode 307, Total Reward: 49.22, Loss: 56.6353, Crashes: 32, Crash Reward: -6.40, Time: 36.82s
# Episode 308, Total Reward: 79.40, Loss: 86.7186, Crashes: 26, Crash Reward: -5.20, Time: 41.10s
# Episode 309, Total Reward: 79.60, Loss: 72.0671, Crashes: 25, Crash Reward: -5.00, Time: 45.16s
# Episode 310, Total Reward: 48.72, Loss: 58.2532, Crashes: 36, Crash Reward: -7.20, Time: 31.15s
# Episode 311, Total Reward: 2.13, Loss: 32.4760, Crashes: 4, Crash Reward: -0.80, Time: 4.55s
# Episode 312, Total Reward: 79.40, Loss: 137.2939, Crashes: 26, Crash Reward: -5.20, Time: 43.60s
# Episode 313, Total Reward: 77.80, Loss: 103.6578, Crashes: 34, Crash Reward: -6.80, Time: 39.99s
# Episode 314, Total Reward: -0.52, Loss: 7.0379, Crashes: 4, Crash Reward: -0.80, Time: 4.42s
# Episode 315, Total Reward: 79.80, Loss: 93.4830, Crashes: 24, Crash Reward: -4.80, Time: 40.97s
# Episode 316, Total Reward: 18.29, Loss: 4.7192, Crashes: 18, Crash Reward: -3.60, Time: 16.00s
# Episode 317, Total Reward: 55.86, Loss: 95.7621, Crashes: 36, Crash Reward: -7.20, Time: 39.66s
# Episode 318, Total Reward: 20.14, Loss: 36.9312, Crashes: 10, Crash Reward: -2.00, Time: 17.34s
# Episode 319, Total Reward: 20.39, Loss: 4.8118, Crashes: 11, Crash Reward: -2.20, Time: 16.09s
# Episode 320, Total Reward: 77.00, Loss: 73.9458, Crashes: 38, Crash Reward: -7.60, Time: 42.30s
# Episode 321, Total Reward: 21.69, Loss: 82.6273, Crashes: 17, Crash Reward: -3.40, Time: 19.25s
# Episode 322, Total Reward: 78.80, Loss: 74.0821, Crashes: 29, Crash Reward: -5.80, Time: 49.77s
# Episode 323, Total Reward: 79.20, Loss: 51.7998, Crashes: 27, Crash Reward: -5.40, Time: 47.80s
# Episode 324, Total Reward: 32.86, Loss: 38.4577, Crashes: 27, Crash Reward: -5.40, Time: 27.30s
# Episode 325, Total Reward: 5.74, Loss: 1.3373, Crashes: 7, Crash Reward: -1.40, Time: 6.15s
# Episode 326, Total Reward: 77.80, Loss: 72.0462, Crashes: 34, Crash Reward: -6.80, Time: 40.77s
# Episode 327, Total Reward: 18.34, Loss: 19.9848, Crashes: 18, Crash Reward: -3.60, Time: 12.99s
# Episode 328, Total Reward: 0.99, Loss: 16.6543, Crashes: 4, Crash Reward: -0.80, Time: 4.48s
# Episode 329, Total Reward: 5.82, Loss: 17.1312, Crashes: 4, Crash Reward: -0.80, Time: 6.83s
# Episode 330, Total Reward: 5.98, Loss: 1.3948, Crashes: 4, Crash Reward: -0.80, Time: 6.30s
# Episode 331, Total Reward: 1.67, Loss: 1.0376, Crashes: 7, Crash Reward: -1.40, Time: 4.53s
# Episode 332, Total Reward: 0.74, Loss: 0.9486, Crashes: 7, Crash Reward: -1.40, Time: 4.54s
# Episode 333, Total Reward: 578.80, Loss: 113.0369, Crashes: 29, Crash Reward: -5.80, Time: 45.24s
# Episode 334, Total Reward: 2.72, Loss: 0.7767, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 335, Total Reward: 48.38, Loss: 71.0667, Crashes: 24, Crash Reward: -4.80, Time: 28.91s
# Episode 336, Total Reward: 1.47, Loss: 1.9625, Crashes: 6, Crash Reward: -1.20, Time: 4.60s
# Episode 337, Total Reward: 17.73, Loss: 50.7799, Crashes: 19, Crash Reward: -3.80, Time: 13.81s
# Episode 338, Total Reward: 80.20, Loss: 164.2808, Crashes: 22, Crash Reward: -4.40, Time: 44.62s
# Episode 339, Total Reward: 18.30, Loss: 5.2273, Crashes: 15, Crash Reward: -3.00, Time: 19.12s
# Episode 340, Total Reward: 79.40, Loss: 59.9328, Crashes: 26, Crash Reward: -5.20, Time: 42.30s
# Episode 341, Total Reward: -0.80, Loss: 16.5553, Crashes: 4, Crash Reward: -0.80, Time: 4.69s
# Episode 342, Total Reward: 20.62, Loss: 19.4618, Crashes: 20, Crash Reward: -4.00, Time: 17.91s
# Episode 343, Total Reward: 2.16, Loss: 0.8683, Crashes: 6, Crash Reward: -1.20, Time: 4.54s
# Episode 344, Total Reward: 577.74, Loss: 54.4286, Crashes: 34, Crash Reward: -6.80, Time: 35.46s
# Episode 345, Total Reward: 1.50, Loss: 0.7736, Crashes: 4, Crash Reward: -0.80, Time: 4.55s
# Episode 346, Total Reward: 56.95, Loss: 52.3889, Crashes: 37, Crash Reward: -7.40, Time: 32.65s
# Episode 347, Total Reward: 5.20, Loss: 31.9754, Crashes: 5, Crash Reward: -1.00, Time: 5.22s
# Episode 348, Total Reward: 76.80, Loss: 102.1539, Crashes: 39, Crash Reward: -7.80, Time: 39.24s
# Episode 349, Total Reward: 47.76, Loss: 6.6384, Crashes: 29, Crash Reward: -5.80, Time: 28.01s
# Episode 350, Total Reward: 579.55, Loss: 23.6362, Crashes: 25, Crash Reward: -5.00, Time: 37.12s
# Episode 351, Total Reward: 7.83, Loss: 2.0667, Crashes: 10, Crash Reward: -2.00, Time: 8.00s
# Episode 352, Total Reward: 2.78, Loss: 1.1567, Crashes: 3, Crash Reward: -0.60, Time: 4.60s
# Episode 353, Total Reward: 51.21, Loss: 73.0168, Crashes: 28, Crash Reward: -5.60, Time: 36.45s
# Episode 354, Total Reward: 575.37, Loss: 52.1594, Crashes: 46, Crash Reward: -9.20, Time: 42.17s
# Episode 355, Total Reward: 20.77, Loss: 32.0464, Crashes: 14, Crash Reward: -2.80, Time: 16.67s
# Episode 356, Total Reward: 3.07, Loss: 1.1607, Crashes: 4, Crash Reward: -0.80, Time: 4.51s
# Episode 357, Total Reward: 18.35, Loss: 7.7246, Crashes: 12, Crash Reward: -2.40, Time: 16.22s
# Episode 358, Total Reward: 20.19, Loss: 52.7019, Crashes: 12, Crash Reward: -2.40, Time: 14.28s
# Episode 359, Total Reward: 5.59, Loss: 18.0176, Crashes: 18, Crash Reward: -3.60, Time: 8.34s
# Episode 360, Total Reward: 18.68, Loss: 67.7284, Crashes: 15, Crash Reward: -3.00, Time: 19.38s
# Episode 361, Total Reward: 577.00, Loss: 106.3431, Crashes: 38, Crash Reward: -7.60, Time: 48.09s
# Episode 362, Total Reward: 48.23, Loss: 103.6491, Crashes: 41, Crash Reward: -8.20, Time: 31.85s
# Episode 363, Total Reward: 19.07, Loss: 83.0764, Crashes: 19, Crash Reward: -3.80, Time: 17.98s
# Episode 364, Total Reward: 77.80, Loss: 104.4146, Crashes: 34, Crash Reward: -6.80, Time: 41.36s
# Episode 365, Total Reward: 19.94, Loss: 28.2020, Crashes: 20, Crash Reward: -4.00, Time: 17.26s
# Episode 366, Total Reward: 1.77, Loss: 17.2844, Crashes: 8, Crash Reward: -1.60, Time: 6.69s
# Episode 367, Total Reward: 577.80, Loss: 51.3587, Crashes: 34, Crash Reward: -6.80, Time: 41.01s
# Episode 368, Total Reward: 76.60, Loss: 51.3152, Crashes: 40, Crash Reward: -8.00, Time: 39.72s
# Episode 369, Total Reward: 1.84, Loss: 15.3931, Crashes: 4, Crash Reward: -0.80, Time: 4.54s
# Episode 370, Total Reward: 49.73, Loss: 71.7640, Crashes: 30, Crash Reward: -6.00, Time: 37.27s
# Episode 371, Total Reward: 1.58, Loss: 1.9085, Crashes: 7, Crash Reward: -1.40, Time: 5.46s
# Episode 372, Total Reward: 1.85, Loss: 1.5247, Crashes: 6, Crash Reward: -1.20, Time: 4.54s
# Episode 373, Total Reward: 5.28, Loss: 18.4880, Crashes: 7, Crash Reward: -1.40, Time: 5.99s
# Episode 374, Total Reward: 79.40, Loss: 138.9787, Crashes: 26, Crash Reward: -5.20, Time: 41.88s
# Episode 375, Total Reward: 2.81, Loss: 19.8220, Crashes: 12, Crash Reward: -2.40, Time: 7.03s
# Episode 376, Total Reward: 75.60, Loss: 76.2093, Crashes: 45, Crash Reward: -9.00, Time: 43.36s
# Episode 377, Total Reward: 4.00, Loss: 2.3232, Crashes: 6, Crash Reward: -1.20, Time: 4.89s
# Episode 378, Total Reward: 2.00, Loss: 16.6429, Crashes: 4, Crash Reward: -0.80, Time: 4.50s
# Episode 379, Total Reward: -0.80, Loss: 1.3960, Crashes: 4, Crash Reward: -0.80, Time: 4.57s
# Episode 380, Total Reward: 32.58, Loss: 22.2388, Crashes: 24, Crash Reward: -4.80, Time: 22.20s
# Episode 381, Total Reward: 20.31, Loss: 23.5121, Crashes: 14, Crash Reward: -2.80, Time: 13.20s
# Episode 382, Total Reward: 34.93, Loss: 6.6020, Crashes: 22, Crash Reward: -4.40, Time: 21.48s
# Episode 383, Total Reward: -0.80, Loss: 16.7654, Crashes: 4, Crash Reward: -0.80, Time: 4.43s
# Episode 384, Total Reward: 4.04, Loss: 15.5858, Crashes: 5, Crash Reward: -1.00, Time: 4.79s
# Episode 385, Total Reward: 21.57, Loss: 48.7811, Crashes: 10, Crash Reward: -2.00, Time: 16.33s
# Episode 386, Total Reward: 47.23, Loss: 55.9818, Crashes: 30, Crash Reward: -6.00, Time: 31.36s
# Episode 387, Total Reward: 18.86, Loss: 40.0851, Crashes: 17, Crash Reward: -3.40, Time: 12.99s
# Episode 388, Total Reward: -0.13, Loss: 6.5610, Crashes: 3, Crash Reward: -0.60, Time: 4.54s
# Episode 389, Total Reward: 3.21, Loss: 30.1022, Crashes: 7, Crash Reward: -1.40, Time: 4.70s
# Episode 390, Total Reward: 1.23, Loss: 3.9175, Crashes: 7, Crash Reward: -1.40, Time: 4.94s
# Episode 391, Total Reward: 2.16, Loss: 19.5551, Crashes: 7, Crash Reward: -1.40, Time: 6.55s
# Episode 392, Total Reward: 577.00, Loss: 66.8281, Crashes: 38, Crash Reward: -7.60, Time: 36.89s
# Episode 393, Total Reward: 4.65, Loss: 18.5061, Crashes: 6, Crash Reward: -1.20, Time: 5.85s
# Episode 394, Total Reward: 76.80, Loss: 138.5880, Crashes: 39, Crash Reward: -7.80, Time: 44.41s
# Episode 395, Total Reward: 22.00, Loss: 25.6062, Crashes: 11, Crash Reward: -2.20, Time: 16.77s
# Episode 396, Total Reward: 78.40, Loss: 109.3781, Crashes: 31, Crash Reward: -6.20, Time: 45.65s
# Episode 397, Total Reward: 3.41, Loss: 5.1478, Crashes: 6, Crash Reward: -1.20, Time: 5.13s
# Episode 398, Total Reward: 18.29, Loss: 76.9350, Crashes: 14, Crash Reward: -2.80, Time: 15.83s
# Router model saved at episode 400
# Episode 399, Total Reward: 5.99, Loss: 6.6381, Crashes: 3, Crash Reward: -0.60, Time: 7.26s
# Episode 400, Total Reward: 19.23, Loss: 8.1837, Crashes: 16, Crash Reward: -3.20, Time: 12.08s
# Episode 401, Total Reward: 78.20, Loss: 153.2001, Crashes: 32, Crash Reward: -6.40, Time: 46.56s
# Episode 402, Total Reward: 23.91, Loss: 57.6570, Crashes: 19, Crash Reward: -3.80, Time: 27.99s
# Episode 403, Total Reward: 3.56, Loss: 3.2579, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 404, Total Reward: 1.92, Loss: 19.3501, Crashes: 7, Crash Reward: -1.40, Time: 4.92s
# Episode 405, Total Reward: 77.40, Loss: 191.1625, Crashes: 36, Crash Reward: -7.20, Time: 45.21s
# Episode 406, Total Reward: 6.49, Loss: 5.3009, Crashes: 3, Crash Reward: -0.60, Time: 6.44s
# Episode 407, Total Reward: 575.20, Loss: 62.8156, Crashes: 47, Crash Reward: -9.40, Time: 33.97s
# Episode 408, Total Reward: 5.36, Loss: 2.2277, Crashes: 6, Crash Reward: -1.20, Time: 5.99s
# Episode 409, Total Reward: 24.23, Loss: 51.3131, Crashes: 16, Crash Reward: -3.20, Time: 20.91s
# Episode 410, Total Reward: 8.90, Loss: 17.3221, Crashes: 8, Crash Reward: -1.60, Time: 6.91s
# Episode 411, Total Reward: 20.18, Loss: 12.7845, Crashes: 15, Crash Reward: -3.00, Time: 16.82s
# Episode 412, Total Reward: 1.62, Loss: 17.0215, Crashes: 8, Crash Reward: -1.60, Time: 4.53s
# Episode 413, Total Reward: 79.40, Loss: 124.4101, Crashes: 26, Crash Reward: -5.20, Time: 47.60s
# Episode 414, Total Reward: -0.15, Loss: 1.4053, Crashes: 3, Crash Reward: -0.60, Time: 4.53s
# Episode 415, Total Reward: 2.49, Loss: 1.3998, Crashes: 6, Crash Reward: -1.20, Time: 4.44s
# Episode 416, Total Reward: 5.07, Loss: 25.9341, Crashes: 7, Crash Reward: -1.40, Time: 6.40s
# Episode 417, Total Reward: 18.41, Loss: 62.6658, Crashes: 12, Crash Reward: -2.40, Time: 13.36s
# Episode 418, Total Reward: 20.34, Loss: 47.8180, Crashes: 10, Crash Reward: -2.00, Time: 14.89s
# Episode 419, Total Reward: 2.81, Loss: 17.2272, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 420, Total Reward: 577.20, Loss: 53.6201, Crashes: 37, Crash Reward: -7.40, Time: 36.00s
# Episode 421, Total Reward: 8.35, Loss: 3.6273, Crashes: 15, Crash Reward: -3.00, Time: 9.71s
# Episode 422, Total Reward: 76.00, Loss: 150.2969, Crashes: 43, Crash Reward: -8.60, Time: 43.17s
# Episode 423, Total Reward: 5.84, Loss: 14.5028, Crashes: 3, Crash Reward: -0.60, Time: 5.95s
# Episode 424, Total Reward: 73.73, Loss: 94.9998, Crashes: 42, Crash Reward: -8.40, Time: 36.76s
# Episode 425, Total Reward: 5.11, Loss: 18.1643, Crashes: 6, Crash Reward: -1.20, Time: 6.44s
# Episode 426, Total Reward: 74.80, Loss: 86.8608, Crashes: 49, Crash Reward: -9.80, Time: 45.00s
# Episode 427, Total Reward: 20.55, Loss: 10.6982, Crashes: 12, Crash Reward: -2.40, Time: 17.25s
# Episode 428, Total Reward: -0.41, Loss: 2.2290, Crashes: 4, Crash Reward: -0.80, Time: 4.54s
# Episode 429, Total Reward: 576.88, Loss: 74.5804, Crashes: 38, Crash Reward: -7.60, Time: 39.01s
# Episode 430, Total Reward: 575.40, Loss: 66.6635, Crashes: 46, Crash Reward: -9.20, Time: 28.74s
# Episode 431, Total Reward: 77.80, Loss: 135.1894, Crashes: 34, Crash Reward: -6.80, Time: 42.82s
# Episode 432, Total Reward: 3.12, Loss: 2.7464, Crashes: 8, Crash Reward: -1.60, Time: 5.14s
# Episode 433, Total Reward: 4.40, Loss: 37.0546, Crashes: 10, Crash Reward: -2.00, Time: 7.92s
# Episode 434, Total Reward: 42.94, Loss: 84.3386, Crashes: 25, Crash Reward: -5.00, Time: 26.05s
# Episode 435, Total Reward: 35.36, Loss: 42.2907, Crashes: 21, Crash Reward: -4.20, Time: 22.74s
# Episode 436, Total Reward: 19.19, Loss: 63.9914, Crashes: 16, Crash Reward: -3.20, Time: 13.45s
# Episode 437, Total Reward: 22.01, Loss: 78.8326, Crashes: 11, Crash Reward: -2.20, Time: 17.36s
# Episode 438, Total Reward: 3.16, Loss: 2.1658, Crashes: 5, Crash Reward: -1.00, Time: 4.58s
# Episode 439, Total Reward: 3.10, Loss: 19.6930, Crashes: 8, Crash Reward: -1.60, Time: 4.93s
# Episode 440, Total Reward: 7.12, Loss: 19.6844, Crashes: 11, Crash Reward: -2.20, Time: 7.12s
# Episode 441, Total Reward: -0.46, Loss: 1.9865, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 442, Total Reward: 74.60, Loss: 183.1993, Crashes: 50, Crash Reward: -10.00, Time: 46.86s
# Episode 443, Total Reward: 19.31, Loss: 31.5188, Crashes: 16, Crash Reward: -3.20, Time: 16.68s
# Episode 444, Total Reward: 48.64, Loss: 137.9476, Crashes: 27, Crash Reward: -5.40, Time: 31.41s
# Episode 445, Total Reward: 1.76, Loss: 36.7643, Crashes: 6, Crash Reward: -1.20, Time: 4.49s
# Episode 446, Total Reward: 7.15, Loss: 28.1321, Crashes: 12, Crash Reward: -2.40, Time: 6.27s
# Episode 447, Total Reward: 75.00, Loss: 131.4333, Crashes: 48, Crash Reward: -9.60, Time: 36.14s
# Episode 448, Total Reward: 6.77, Loss: 14.7289, Crashes: 12, Crash Reward: -2.40, Time: 9.49s
# Episode 449, Total Reward: -0.80, Loss: 19.0614, Crashes: 4, Crash Reward: -0.80, Time: 4.40s
# Episode 450, Total Reward: 5.33, Loss: 61.2578, Crashes: 10, Crash Reward: -2.00, Time: 7.51s
# Episode 451, Total Reward: 2.54, Loss: 4.9898, Crashes: 8, Crash Reward: -1.60, Time: 4.72s
# Episode 452, Total Reward: 1.36, Loss: 8.0534, Crashes: 8, Crash Reward: -1.60, Time: 4.60s
# Episode 453, Total Reward: 62.78, Loss: 157.2158, Crashes: 18, Crash Reward: -3.60, Time: 39.61s
# Episode 454, Total Reward: 5.10, Loss: 34.3150, Crashes: 5, Crash Reward: -1.00, Time: 5.86s
# Episode 455, Total Reward: 5.47, Loss: 19.5502, Crashes: 6, Crash Reward: -1.20, Time: 7.33s
# Episode 456, Total Reward: 23.48, Loss: 74.7386, Crashes: 10, Crash Reward: -2.00, Time: 18.61s
# Episode 457, Total Reward: 577.40, Loss: 74.3242, Crashes: 36, Crash Reward: -7.20, Time: 38.01s
# Episode 458, Total Reward: 2.67, Loss: 6.0788, Crashes: 5, Crash Reward: -1.00, Time: 5.01s
# Episode 459, Total Reward: 78.00, Loss: 119.2410, Crashes: 33, Crash Reward: -6.60, Time: 37.96s
# Episode 460, Total Reward: 55.48, Loss: 62.4818, Crashes: 38, Crash Reward: -7.60, Time: 31.44s
# Episode 461, Total Reward: 52.94, Loss: 113.9021, Crashes: 22, Crash Reward: -4.40, Time: 35.28s
# Episode 462, Total Reward: 18.99, Loss: 65.9007, Crashes: 13, Crash Reward: -2.60, Time: 15.32s
# Episode 463, Total Reward: 75.80, Loss: 122.4463, Crashes: 44, Crash Reward: -8.80, Time: 37.18s
# Episode 464, Total Reward: 19.65, Loss: 23.1337, Crashes: 15, Crash Reward: -3.00, Time: 10.79s
# Episode 465, Total Reward: 578.60, Loss: 168.4760, Crashes: 30, Crash Reward: -6.00, Time: 34.17s
# Episode 466, Total Reward: 8.11, Loss: 18.1363, Crashes: 8, Crash Reward: -1.60, Time: 6.99s
# Episode 467, Total Reward: 19.38, Loss: 62.5380, Crashes: 13, Crash Reward: -2.60, Time: 13.64s
# Episode 468, Total Reward: 577.20, Loss: 122.4600, Crashes: 37, Crash Reward: -7.40, Time: 42.23s
# Episode 469, Total Reward: 20.41, Loss: 103.3680, Crashes: 8, Crash Reward: -1.60, Time: 15.19s
# Episode 470, Total Reward: 49.86, Loss: 152.4092, Crashes: 26, Crash Reward: -5.20, Time: 37.75s
# Episode 471, Total Reward: 77.60, Loss: 142.8216, Crashes: 35, Crash Reward: -7.00, Time: 39.96s
# Episode 472, Total Reward: 77.40, Loss: 95.1513, Crashes: 36, Crash Reward: -7.20, Time: 31.97s
# Episode 473, Total Reward: 0.40, Loss: 24.1811, Crashes: 4, Crash Reward: -0.80, Time: 4.59s
# Episode 474, Total Reward: 23.93, Loss: 53.7692, Crashes: 20, Crash Reward: -4.00, Time: 19.16s
# Episode 475, Total Reward: 7.03, Loss: 34.2789, Crashes: 11, Crash Reward: -2.20, Time: 8.78s
# Episode 476, Total Reward: 4.20, Loss: 21.1230, Crashes: 7, Crash Reward: -1.40, Time: 5.56s
# Episode 477, Total Reward: 76.80, Loss: 101.3714, Crashes: 39, Crash Reward: -7.80, Time: 31.51s
# Episode 478, Total Reward: 578.00, Loss: 115.5249, Crashes: 33, Crash Reward: -6.60, Time: 44.75s
# Episode 479, Total Reward: 2.60, Loss: 9.2507, Crashes: 7, Crash Reward: -1.40, Time: 4.77s
# Episode 480, Total Reward: 70.96, Loss: 128.9147, Crashes: 34, Crash Reward: -6.80, Time: 38.00s
# Episode 481, Total Reward: 76.20, Loss: 175.9623, Crashes: 42, Crash Reward: -8.40, Time: 36.60s
# Episode 482, Total Reward: 20.03, Loss: 60.1344, Crashes: 14, Crash Reward: -2.80, Time: 17.95s
# Episode 483, Total Reward: 1.71, Loss: 18.2843, Crashes: 5, Crash Reward: -1.00, Time: 4.58s
# Episode 484, Total Reward: 5.18, Loss: 13.9639, Crashes: 5, Crash Reward: -1.00, Time: 6.54s
# Episode 485, Total Reward: 2.39, Loss: 3.2183, Crashes: 3, Crash Reward: -0.60, Time: 4.53s
# Episode 486, Total Reward: 2.66, Loss: 2.9657, Crashes: 5, Crash Reward: -1.00, Time: 4.57s
# Episode 487, Total Reward: 3.81, Loss: 16.7891, Crashes: 6, Crash Reward: -1.20, Time: 5.18s
# Episode 488, Total Reward: 4.93, Loss: 7.4335, Crashes: 7, Crash Reward: -1.40, Time: 7.94s
# Episode 489, Total Reward: 6.17, Loss: 43.3061, Crashes: 8, Crash Reward: -1.60, Time: 7.44s
# Episode 490, Total Reward: 77.60, Loss: 117.7391, Crashes: 35, Crash Reward: -7.00, Time: 39.86s
# Episode 491, Total Reward: 1.94, Loss: 23.8073, Crashes: 7, Crash Reward: -1.40, Time: 4.54s
# Episode 492, Total Reward: 4.33, Loss: 3.7206, Crashes: 7, Crash Reward: -1.40, Time: 6.10s
# ...
# Episode 1286, Total Reward: 76.80, Loss: 913.5907, Crashes: 39, Crash Reward: -7.80, Time: 41.65s
# Episode 1287, Total Reward: 6.62, Loss: 104.6228, Crashes: 3, Crash Reward: -0.60, Time: 6.75s
# Episode 1288, Total Reward: 4.00, Loss: 53.4658, Crashes: 6, Crash Reward: -1.20, Time: 5.09s
# Episode 1289, Total Reward: 2.56, Loss: 37.8159, Crashes: 6, Crash Reward: -1.20, Time: 4.64s
# Episode 1290, Total Reward: 78.00, Loss: 765.0414, Crashes: 33, Crash Reward: -6.60, Time: 44.97s
# Episode 1291, Total Reward: 578.80, Loss: 617.4623, Crashes: 29, Crash Reward: -5.80, Time: 33.84s
# Episode 1292, Total Reward: 8.21, Loss: 96.5819, Crashes: 6, Crash Reward: -1.20, Time: 6.64s
# Episode 1293, Total Reward: -0.80, Loss: 77.6704, Crashes: 4, Crash Reward: -0.80, Time: 4.54s
# Episode 1294, Total Reward: 77.00, Loss: 677.7216, Crashes: 38, Crash Reward: -7.60, Time: 38.77s
# Episode 1295, Total Reward: 45.92, Loss: 426.5240, Crashes: 23, Crash Reward: -4.60, Time: 22.92s
# Episode 1296, Total Reward: -0.60, Loss: 72.4898, Crashes: 3, Crash Reward: -0.60, Time: 4.59s
# Episode 1297, Total Reward: 18.07, Loss: 266.0526, Crashes: 14, Crash Reward: -2.80, Time: 15.58s
# Episode 1298, Total Reward: 78.80, Loss: 741.5442, Crashes: 29, Crash Reward: -5.80, Time: 45.86s
# Router model saved at episode 1300
# Episode 1299, Total Reward: 78.40, Loss: 823.1003, Crashes: 31, Crash Reward: -6.20, Time: 48.49s
# Episode 1300, Total Reward: 79.60, Loss: 760.9151, Crashes: 25, Crash Reward: -5.00, Time: 40.49s
# Episode 1301, Total Reward: 48.87, Loss: 544.1691, Crashes: 30, Crash Reward: -6.00, Time: 32.17s
# Episode 1302, Total Reward: 52.39, Loss: 543.8768, Crashes: 20, Crash Reward: -4.00, Time: 30.11s
# Episode 1303, Total Reward: 1.89, Loss: 55.7047, Crashes: 7, Crash Reward: -1.40, Time: 4.54s
# Episode 1304, Total Reward: 4.30, Loss: 81.5883, Crashes: 9, Crash Reward: -1.80, Time: 6.53s
# Episode 1305, Total Reward: 17.83, Loss: 304.0026, Crashes: 19, Crash Reward: -3.80, Time: 18.09s
# Episode 1306, Total Reward: 69.11, Loss: 570.0095, Crashes: 40, Crash Reward: -8.00, Time: 36.78s
# Episode 1307, Total Reward: 48.54, Loss: 435.3984, Crashes: 34, Crash Reward: -6.80, Time: 28.11s
# Episode 1308, Total Reward: 74.80, Loss: 657.0094, Crashes: 49, Crash Reward: -9.80, Time: 43.20s
# Episode 1309, Total Reward: 2.20, Loss: 73.7858, Crashes: 4, Crash Reward: -0.80, Time: 4.39s
# Episode 1310, Total Reward: 4.17, Loss: 95.9881, Crashes: 8, Crash Reward: -1.60, Time: 6.07s
# Episode 1311, Total Reward: 3.55, Loss: 67.3223, Crashes: 5, Crash Reward: -1.00, Time: 4.78s
# Episode 1312, Total Reward: 1.52, Loss: 51.8652, Crashes: 8, Crash Reward: -1.60, Time: 4.58s
# Episode 1313, Total Reward: 2.25, Loss: 35.4969, Crashes: 4, Crash Reward: -0.80, Time: 4.55s
# Episode 1314, Total Reward: 6.30, Loss: 121.6177, Crashes: 8, Crash Reward: -1.60, Time: 6.28s
# Episode 1315, Total Reward: 578.60, Loss: 763.7446, Crashes: 30, Crash Reward: -6.00, Time: 43.69s
# Episode 1316, Total Reward: 5.62, Loss: 132.5545, Crashes: 10, Crash Reward: -2.00, Time: 7.60s
# Episode 1317, Total Reward: -0.60, Loss: 59.6844, Crashes: 3, Crash Reward: -0.60, Time: 4.54s
# Episode 1318, Total Reward: 20.32, Loss: 260.5885, Crashes: 12, Crash Reward: -2.40, Time: 16.94s
# Episode 1319, Total Reward: 17.95, Loss: 197.9370, Crashes: 23, Crash Reward: -4.60, Time: 12.17s
# Episode 1320, Total Reward: 576.80, Loss: 627.5025, Crashes: 39, Crash Reward: -7.80, Time: 38.10s
# Episode 1321, Total Reward: 1.98, Loss: 53.6911, Crashes: 8, Crash Reward: -1.60, Time: 4.67s
# Episode 1322, Total Reward: 4.10, Loss: 64.8730, Crashes: 6, Crash Reward: -1.20, Time: 5.13s
# Episode 1323, Total Reward: 19.66, Loss: 305.9444, Crashes: 14, Crash Reward: -2.80, Time: 16.59s
# Episode 1324, Total Reward: 78.40, Loss: 652.9160, Crashes: 31, Crash Reward: -6.20, Time: 41.51s
# Episode 1325, Total Reward: 14.17, Loss: 212.2933, Crashes: 18, Crash Reward: -3.60, Time: 12.60s
# Episode 1326, Total Reward: 19.85, Loss: 382.1543, Crashes: 15, Crash Reward: -3.00, Time: 20.35s
# Episode 1327, Total Reward: 20.97, Loss: 211.6569, Crashes: 14, Crash Reward: -2.80, Time: 17.10s
# Episode 1328, Total Reward: 16.08, Loss: 204.8281, Crashes: 8, Crash Reward: -1.60, Time: 15.15s
# Episode 1329, Total Reward: 77.80, Loss: 733.1509, Crashes: 34, Crash Reward: -6.80, Time: 47.22s
# Episode 1330, Total Reward: 2.81, Loss: 102.1910, Crashes: 7, Crash Reward: -1.40, Time: 6.09s
# Episode 1331, Total Reward: 3.74, Loss: 52.9010, Crashes: 4, Crash Reward: -0.80, Time: 5.58s
# Episode 1332, Total Reward: 0.68, Loss: 66.2382, Crashes: 7, Crash Reward: -1.40, Time: 4.33s
# Episode 1333, Total Reward: 5.83, Loss: 108.4580, Crashes: 6, Crash Reward: -1.20, Time: 7.37s
# Episode 1334, Total Reward: 2.04, Loss: 42.0742, Crashes: 4, Crash Reward: -0.80, Time: 4.48s
# Episode 1335, Total Reward: 1.62, Loss: 65.9420, Crashes: 6, Crash Reward: -1.20, Time: 4.80s
# Episode 1336, Total Reward: 78.40, Loss: 625.6355, Crashes: 31, Crash Reward: -6.20, Time: 46.01s
# Episode 1337, Total Reward: 577.80, Loss: 660.2609, Crashes: 34, Crash Reward: -6.80, Time: 41.81s
# Episode 1338, Total Reward: 1.73, Loss: 51.6249, Crashes: 5, Crash Reward: -1.00, Time: 4.67s
# Episode 1339, Total Reward: 20.22, Loss: 189.6615, Crashes: 10, Crash Reward: -2.00, Time: 11.24s
# Episode 1340, Total Reward: 23.83, Loss: 310.5431, Crashes: 9, Crash Reward: -1.80, Time: 18.30s
# Episode 1341, Total Reward: 578.80, Loss: 769.7976, Crashes: 29, Crash Reward: -5.80, Time: 41.04s
# Episode 1342, Total Reward: 51.70, Loss: 594.3013, Crashes: 30, Crash Reward: -6.00, Time: 31.53s
# Episode 1343, Total Reward: 2.62, Loss: 82.7108, Crashes: 4, Crash Reward: -0.80, Time: 4.53s
# Episode 1344, Total Reward: 20.88, Loss: 307.1366, Crashes: 11, Crash Reward: -2.20, Time: 17.87s
# Episode 1345, Total Reward: 7.84, Loss: 82.5198, Crashes: 7, Crash Reward: -1.40, Time: 6.07s
# Episode 1346, Total Reward: 2.12, Loss: 94.7476, Crashes: 4, Crash Reward: -0.80, Time: 4.57s
# Episode 1347, Total Reward: 2.97, Loss: 45.3847, Crashes: 8, Crash Reward: -1.60, Time: 4.74s
# Episode 1348, Total Reward: 19.96, Loss: 199.6710, Crashes: 14, Crash Reward: -2.80, Time: 13.05s
# Episode 1349, Total Reward: 3.65, Loss: 69.1426, Crashes: 9, Crash Reward: -1.80, Time: 4.89s
# Episode 1350, Total Reward: 77.40, Loss: 733.1058, Crashes: 36, Crash Reward: -7.20, Time: 49.84s
# Episode 1351, Total Reward: 5.95, Loss: 110.1661, Crashes: 9, Crash Reward: -1.80, Time: 6.91s
# Episode 1352, Total Reward: 2.38, Loss: 96.6181, Crashes: 8, Crash Reward: -1.60, Time: 5.59s
# Episode 1353, Total Reward: 578.80, Loss: 705.9178, Crashes: 29, Crash Reward: -5.80, Time: 45.26s
# Episode 1354, Total Reward: 579.20, Loss: 751.8020, Crashes: 27, Crash Reward: -5.40, Time: 44.60s
# Episode 1355, Total Reward: 20.08, Loss: 260.8256, Crashes: 8, Crash Reward: -1.60, Time: 16.85s
# Episode 1356, Total Reward: 4.54, Loss: 61.0970, Crashes: 6, Crash Reward: -1.20, Time: 4.81s
# Episode 1357, Total Reward: 77.60, Loss: 692.0937, Crashes: 35, Crash Reward: -7.00, Time: 37.55s
# Episode 1358, Total Reward: 0.82, Loss: 89.2969, Crashes: 10, Crash Reward: -2.00, Time: 6.56s
# Episode 1359, Total Reward: 576.80, Loss: 556.2997, Crashes: 39, Crash Reward: -7.80, Time: 34.50s
# Episode 1360, Total Reward: 1.23, Loss: 66.6739, Crashes: 4, Crash Reward: -0.80, Time: 4.55s
# Episode 1361, Total Reward: 53.12, Loss: 495.4879, Crashes: 19, Crash Reward: -3.80, Time: 33.34s
# Episode 1362, Total Reward: 2.51, Loss: 84.7989, Crashes: 6, Crash Reward: -1.20, Time: 4.44s
# Episode 1363, Total Reward: 48.25, Loss: 514.6019, Crashes: 28, Crash Reward: -5.60, Time: 31.16s
# Episode 1364, Total Reward: 6.26, Loss: 80.9888, Crashes: 1, Crash Reward: -0.20, Time: 5.89s
# Episode 1365, Total Reward: 1.59, Loss: 44.9418, Crashes: 5, Crash Reward: -1.00, Time: 4.56s
# Episode 1366, Total Reward: 1.78, Loss: 69.2488, Crashes: 3, Crash Reward: -0.60, Time: 4.58s
# Episode 1367, Total Reward: 3.10, Loss: 68.1494, Crashes: 3, Crash Reward: -0.60, Time: 4.59s
# Episode 1368, Total Reward: 46.87, Loss: 403.7171, Crashes: 27, Crash Reward: -5.40, Time: 30.00s
# Episode 1369, Total Reward: 1.28, Loss: 58.9793, Crashes: 6, Crash Reward: -1.20, Time: 4.54s
# Episode 1370, Total Reward: 0.50, Loss: 48.4491, Crashes: 6, Crash Reward: -1.20, Time: 4.44s
# Episode 1371, Total Reward: 6.00, Loss: 101.2381, Crashes: 2, Crash Reward: -0.40, Time: 7.78s
# Episode 1372, Total Reward: 79.60, Loss: 792.0638, Crashes: 25, Crash Reward: -5.00, Time: 44.91s
# Episode 1373, Total Reward: 33.29, Loss: 323.3731, Crashes: 19, Crash Reward: -3.80, Time: 20.32s
# Episode 1374, Total Reward: 24.29, Loss: 362.7035, Crashes: 15, Crash Reward: -3.00, Time: 21.38s
# Episode 1375, Total Reward: 29.17, Loss: 450.8771, Crashes: 23, Crash Reward: -4.60, Time: 24.75s
# Episode 1376, Total Reward: 18.36, Loss: 197.1815, Crashes: 15, Crash Reward: -3.00, Time: 16.07s
# Episode 1377, Total Reward: 4.54, Loss: 88.5452, Crashes: 5, Crash Reward: -1.00, Time: 5.88s
# Episode 1378, Total Reward: 5.63, Loss: 113.7182, Crashes: 9, Crash Reward: -1.80, Time: 6.69s
# Episode 1379, Total Reward: 5.69, Loss: 72.2142, Crashes: 6, Crash Reward: -1.20, Time: 6.89s
# Episode 1380, Total Reward: 3.55, Loss: 65.5869, Crashes: 3, Crash Reward: -0.60, Time: 4.59s
# Episode 1381, Total Reward: 2.00, Loss: 53.0470, Crashes: 7, Crash Reward: -1.40, Time: 4.54s
# Episode 1382, Total Reward: 5.31, Loss: 122.2631, Crashes: 10, Crash Reward: -2.00, Time: 7.14s
# Episode 1383, Total Reward: 20.97, Loss: 292.3388, Crashes: 11, Crash Reward: -2.20, Time: 19.13s
# Episode 1384, Total Reward: 3.69, Loss: 74.7272, Crashes: 5, Crash Reward: -1.00, Time: 4.93s
# Episode 1385, Total Reward: 35.31, Loss: 421.4653, Crashes: 24, Crash Reward: -4.80, Time: 25.12s
# Episode 1386, Total Reward: 6.33, Loss: 76.3060, Crashes: 4, Crash Reward: -0.80, Time: 5.87s
# Episode 1387, Total Reward: 4.95, Loss: 165.4448, Crashes: 11, Crash Reward: -2.20, Time: 7.40s
# Episode 1388, Total Reward: 6.89, Loss: 98.6058, Crashes: 5, Crash Reward: -1.00, Time: 8.50s
# Episode 1389, Total Reward: 2.00, Loss: 78.6245, Crashes: 5, Crash Reward: -1.00, Time: 4.68s
# Episode 1390, Total Reward: 4.31, Loss: 86.6270, Crashes: 8, Crash Reward: -1.60, Time: 6.05s
# Episode 1391, Total Reward: 18.33, Loss: 169.8866, Crashes: 17, Crash Reward: -3.40, Time: 13.73s
# Episode 1392, Total Reward: 26.46, Loss: 413.2790, Crashes: 17, Crash Reward: -3.40, Time: 24.83s
# Episode 1393, Total Reward: 4.27, Loss: 68.9461, Crashes: 5, Crash Reward: -1.00, Time: 4.76s
# Episode 1394, Total Reward: 20.39, Loss: 221.6039, Crashes: 19, Crash Reward: -3.80, Time: 17.83s
# Episode 1395, Total Reward: 3.43, Loss: 58.1678, Crashes: 7, Crash Reward: -1.40, Time: 4.83s
# Episode 1396, Total Reward: 1.78, Loss: 42.3482, Crashes: 6, Crash Reward: -1.20, Time: 4.56s
# Episode 1397, Total Reward: -1.00, Loss: 50.5794, Crashes: 5, Crash Reward: -1.00, Time: 4.63s
# Episode 1398, Total Reward: 52.95, Loss: 474.9353, Crashes: 34, Crash Reward: -6.80, Time: 32.25s
# Router model saved at episode 1400
# Episode 1399, Total Reward: 19.65, Loss: 174.7436, Crashes: 16, Crash Reward: -3.20, Time: 14.99s
# Episode 1400, Total Reward: 7.59, Loss: 105.5327, Crashes: 8, Crash Reward: -1.60, Time: 10.12s
# Episode 1401, Total Reward: 77.20, Loss: 715.3212, Crashes: 37, Crash Reward: -7.40, Time: 40.73s
# Episode 1402, Total Reward: 5.99, Loss: 94.5031, Crashes: 6, Crash Reward: -1.20, Time: 5.94s
# Episode 1403, Total Reward: 19.35, Loss: 263.6862, Crashes: 12, Crash Reward: -2.40, Time: 13.40s
# Episode 1404, Total Reward: 7.74, Loss: 91.9239, Crashes: 5, Crash Reward: -1.00, Time: 6.60s
# Episode 1405, Total Reward: 2.00, Loss: 63.4061, Crashes: 4, Crash Reward: -0.80, Time: 4.59s
# Episode 1406, Total Reward: -0.80, Loss: 60.3172, Crashes: 4, Crash Reward: -0.80, Time: 4.60s
# Episode 1407, Total Reward: 18.22, Loss: 259.6730, Crashes: 18, Crash Reward: -3.60, Time: 15.02s
# Episode 1408, Total Reward: 1.93, Loss: 76.6906, Crashes: 6, Crash Reward: -1.20, Time: 4.53s
# Episode 1409, Total Reward: 4.68, Loss: 97.8459, Crashes: 9, Crash Reward: -1.80, Time: 7.43s
# Episode 1410, Total Reward: 3.34, Loss: 64.1289, Crashes: 4, Crash Reward: -0.80, Time: 4.60s
# Episode 1411, Total Reward: 2.68, Loss: 50.9897, Crashes: 6, Crash Reward: -1.20, Time: 4.61s
# Episode 1412, Total Reward: 2.54, Loss: 72.4474, Crashes: 3, Crash Reward: -0.60, Time: 4.63s
# Episode 1413, Total Reward: 4.84, Loss: 90.9816, Crashes: 11, Crash Reward: -2.20, Time: 6.30s
# Episode 1414, Total Reward: 19.97, Loss: 322.1351, Crashes: 11, Crash Reward: -2.20, Time: 21.34s
# Episode 1415, Total Reward: 41.03, Loss: 267.6629, Crashes: 14, Crash Reward: -2.80, Time: 22.07s
# Episode 1416, Total Reward: 8.11, Loss: 121.5032, Crashes: 8, Crash Reward: -1.60, Time: 7.48s
# Episode 1417, Total Reward: -0.78, Loss: 78.5102, Crashes: 4, Crash Reward: -0.80, Time: 4.92s
# Episode 1418, Total Reward: 2.74, Loss: 40.0165, Crashes: 6, Crash Reward: -1.20, Time: 4.73s
# Episode 1419, Total Reward: 5.55, Loss: 82.3303, Crashes: 4, Crash Reward: -0.80, Time: 4.90s
# Episode 1420, Total Reward: 7.23, Loss: 70.6086, Crashes: 9, Crash Reward: -1.80, Time: 6.40s
# Episode 1421, Total Reward: 42.56, Loss: 440.5108, Crashes: 34, Crash Reward: -6.80, Time: 27.66s
# Episode 1422, Total Reward: 17.28, Loss: 176.7361, Crashes: 18, Crash Reward: -3.60, Time: 14.07s
# Episode 1423, Total Reward: 21.57, Loss: 118.1571, Crashes: 15, Crash Reward: -3.00, Time: 14.57s
# Episode 1424, Total Reward: 78.00, Loss: 517.7612, Crashes: 33, Crash Reward: -6.60, Time: 40.24s
# Episode 1425, Total Reward: 578.95, Loss: 580.0036, Crashes: 28, Crash Reward: -5.60, Time: 44.69s
# Episode 1426, Total Reward: 8.38, Loss: 85.3421, Crashes: 6, Crash Reward: -1.20, Time: 7.50s
# Episode 1427, Total Reward: 3.36, Loss: 40.2025, Crashes: 8, Crash Reward: -1.60, Time: 4.78s
# Episode 1428, Total Reward: 6.23, Loss: 61.7028, Crashes: 3, Crash Reward: -0.60, Time: 6.11s
# Episode 1429, Total Reward: -0.80, Loss: 56.1924, Crashes: 4, Crash Reward: -0.80, Time: 4.59s
# Episode 1430, Total Reward: 5.98, Loss: 69.6951, Crashes: 5, Crash Reward: -1.00, Time: 6.00s
# Episode 1431, Total Reward: 79.60, Loss: 702.6076, Crashes: 25, Crash Reward: -5.00, Time: 48.26s
# Episode 1432, Total Reward: 70.32, Loss: 513.9277, Crashes: 35, Crash Reward: -7.00, Time: 35.70s
# Episode 1433, Total Reward: 1.81, Loss: 52.6572, Crashes: 7, Crash Reward: -1.40, Time: 4.53s
# Exception in thread Thread-462053 (__send_act_get_obs_and_wait):
# Traceback (most recent call last):
#   File "d:\mini_conda\envs\collabkart\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "d:\mini_conda\envs\collabkart\Lib\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "d:\mini_conda\envs\collabkart\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "d:\mini_conda\envs\collabkart\Lib\site-packages\rtgym\envs\real_time_env.py", line 438, in __send_act_get_obs_and_wait
#     self.__update_obs_rew_terminated_truncated()  # capture observation
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\mini_conda\envs\collabkart\Lib\site-packages\rtgym\envs\real_time_env.py", line 452, in __update_obs_rew_terminated_truncated
#     o, r, d, i = self.interface.get_obs_rew_terminated_info()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\mini_conda\envs\collabkart\Lib\site-packages\tmrl\custom\custom_gym_interfaces.py", line 189, in get_obs_rew_terminated_info
#     data, img = self.grab_data_and_img()
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\mini_conda\envs\collabkart\Lib\site-packages\tmrl\custom\custom_gym_interfaces.py", line 125, in grab_data_and_img
#     data = self.client.retrieve_data()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\mini_conda\envs\collabkart\Lib\site-packages\tmrl\custom\utils\tools.py", line 72, in retrieve_data
#     assert t_now - t_start < timeout, f"OpenPlanet stopped sending data since more than {timeout}s."
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: OpenPlanet stopped sending data since more than 10.0s.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
from tmrl import get_environment
import os
import time
import wandb
from collections import deque, defaultdict
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# SimpleDQN and SimpleDQNAgent classes remain the same as in the provided code

class Router(nn.Module):
    def __init__(self, num_experts):
        super(Router, self).__init__()
        self.conv1 = nn.Conv2d(4, 16, kernel_size=3, stride=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=2)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=3, stride=2)
        self.fc = nn.Linear(32 * 7 * 7, num_experts)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        return F.softmax(self.fc(x), dim=1)

class MixtureOfExpertsDQN:
    def __init__(self, expert_agents, learning_rate=0.001, gamma=0.99):
        self.expert_agents = expert_agents
        self.num_experts = len(expert_agents)
        self.router = Router(self.num_experts).to(device)
        self.optimizer = optim.Adam(self.router.parameters(), lr=learning_rate)
        self.gamma = gamma

    def select_action(self, state):
        with torch.no_grad():
            image = torch.FloatTensor(state[3]).unsqueeze(0).to(device)
            additional_inputs = torch.FloatTensor(np.concatenate([state[0], state[1], state[2], state[4], state[5]])).unsqueeze(0).to(device)
            expert_probs = self.router(image)
            
            expert_idx = expert_probs.argmax().item()
            selected_expert = self.expert_agents[expert_idx]
            
            return selected_expert.select_action(state), expert_idx

    def train_step(self, experiences, update_router=True):
        if update_router:
            self.train_router(experiences)
        else:
            self.train_experts(experiences)

    def train_router(self, experiences):
        states, actions, rewards, next_states, dones = zip(*experiences)
        
        states_image = torch.FloatTensor(np.array([state[3] for state in states])).to(device)
        states_additional = torch.FloatTensor(np.array([np.concatenate([state[0], state[1], state[2], state[4], state[5]]) for state in states])).to(device)
        next_states_image = torch.FloatTensor(np.array([state[3] for state in next_states])).to(device)
        next_states_additional = torch.FloatTensor(np.array([np.concatenate([state[0], state[1], state[2], state[4], state[5]]) for state in next_states])).to(device)
        actions = torch.LongTensor(actions).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(dones).to(device)

        expert_probs = self.router(states_image)
        
        current_q_values = torch.zeros(len(experiences), self.expert_agents[0].n_actions).to(device)
        next_q_values = torch.zeros(len(experiences), self.expert_agents[0].n_actions).to(device)

        for i, expert in enumerate(self.expert_agents):
            current_q_values += expert_probs[:, i].unsqueeze(1) * expert.policy_net(states_image, states_additional)
            next_q_values += expert_probs[:, i].unsqueeze(1) * expert.target_net(next_states_image, next_states_additional)

        target_q_values = rewards + (1 - dones) * self.gamma * next_q_values.max(1)[0]
        loss = F.smooth_l1_loss(current_q_values.gather(1, actions.unsqueeze(1)), target_q_values.unsqueeze(1))

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def train_experts(self, experiences_dict):
        losses = []
        for expert_idx, experiences in experiences_dict.items():
            if experiences:
                expert = self.expert_agents[expert_idx]
                for experience in experiences:
                    expert.remember(*experience)
                loss = expert.replay()
                if loss is not None:
                    losses.append(loss)
        return np.mean(losses) if losses else None

    def update_target_networks(self):
        for expert in self.expert_agents:
            expert.update_target_network()

    def save_model(self, path):
        if not os.path.exists(path):
            os.makedirs(path)
        torch.save({
            'router_state_dict': self.router.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
        }, os.path.join(path, 'moe_model.pth'))
        for i, expert in enumerate(self.expert_agents):
            expert.save_checkpoint(episode=0, directory=os.path.join(path, f'expert_{i}'))

    def load_model(self, path):
        checkpoint = torch.load(os.path.join(path, 'moe_model.pth'))
        self.router.load_state_dict(checkpoint['router_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

def train_mixture_of_experts(env, moe_agent, num_episodes, max_steps_per_episode):
    total_crashes = 0
    total_time = 0
    total_loss = 0
    expert_usage = [0] * moe_agent.num_experts

    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = preprocess_observation(obs)
        total_reward = 0
        episode_crashes = 0
        episode_loss = 0
        episode_start_time = time.time()
        prev_obs = None
        episode_expert_usage = [0] * moe_agent.num_experts
        
        update_router = episode % 2 == 0  # Alternate between updating router and experts
        experiences = []
        experiences_dict = defaultdict(list)

        for step in range(max_steps_per_episode):
            agent_action, expert_idx = moe_agent.select_action(state)
            expert_usage[expert_idx] += 1
            episode_expert_usage[expert_idx] += 1
            env_action = agent_action_to_env_action(agent_action.item(), moe_agent.expert_agents[0].n_actions)
            next_obs, env_reward, terminated, truncated, _ = env.step(env_action)
            next_state = preprocess_observation(next_obs)
            done = terminated or truncated

            if detect_crash(next_obs, prev_obs):
                episode_crashes += 1
                env_reward -= 2  # Penalty for crashing

            experience = (state, agent_action.item(), env_reward, next_state, done)
            experiences.append(experience)
            experiences_dict[expert_idx].append(experience)

            state = next_state
            prev_obs = next_obs
            total_reward += env_reward

            if done:
                break

        if update_router:
            loss = moe_agent.train_step(experiences, update_router=True)
        else:
            loss = moe_agent.train_step(experiences_dict, update_router=False)

        if loss is not None:
            episode_loss = loss
            total_loss += episode_loss

        episode_time = time.time() - episode_start_time
        total_time += episode_time
        total_crashes += episode_crashes

        if episode % 10 == 0:
            moe_agent.update_target_networks()

        # Calculate expert usage ratio
        total_expert_usage = sum(episode_expert_usage)
        expert_usage_ratio = [usage / total_expert_usage for usage in episode_expert_usage]

        # Log metrics to wandb
        wandb.log({
            "episode": episode,
            "total_reward": total_reward,
            "crashes": episode_crashes,
            "time": episode_time,
            "loss": episode_loss,
            "epsilon": moe_agent.expert_agents[0].epsilon,  # Assuming all experts have the same epsilon
            "average_reward": total_reward / (step + 1),
            "total_crashes": total_crashes,
            "total_time": total_time,
            "average_loss": total_loss / (episode + 1),
            "episode_duration": episode_time,
            "experts_used": sum(1 for usage in episode_expert_usage if usage > 0),
            "update_router": update_router,
        })

        for i, usage in enumerate(episode_expert_usage):
            wandb.log({
                f"expert_{i}_usage": usage,
                f"expert_{i}_usage_ratio": expert_usage_ratio[i]
            })

        print(f"Episode {episode}, Total Reward: {total_reward:.2f}, Crashes: {episode_crashes}, Time: {episode_time:.2f}s, Loss: {episode_loss:.4f}, Update Router: {update_router}")

        # Save model every 100 episodes
        if episode % 100 == 0:
            moe_agent.save_model(f"checkpoints_moe_dynamic/episode_{episode}")

def test_mixture_of_experts(env, moe_agent, num_episodes, max_steps_per_episode):
    total_rewards = []
    total_crashes = 0
    total_time = 0
    expert_usage = [0] * moe_agent.num_experts
    
    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = preprocess_observation(obs)
        total_reward = 0
        episode_crashes = 0
        episode_start_time = time.time()
        prev_obs = None
        episode_expert_usage = [0] * moe_agent.num_experts
        
        for step in range(max_steps_per_episode):
            agent_action, expert_idx = moe_agent.select_action(state)
            expert_usage[expert_idx] += 1
            episode_expert_usage[expert_idx] += 1
            env_action = agent_action_to_env_action(agent_action.item(), moe_agent.expert_agents[0].n_actions)
            next_obs, reward, terminated, truncated, _ = env.step(env_action)
            next_state = preprocess_observation(next_obs)
            done = terminated or truncated

            if detect_crash(next_obs, prev_obs):
                episode_crashes += 1

            state = next_state
            prev_obs = next_obs
            total_reward += reward

            if done:
                break

        episode_time = time.time() - episode_start_time
        total_time += episode_time
        total_crashes += episode_crashes
        total_rewards.append(total_reward)

        # Calculate expert usage ratio
        total_expert_usage = sum(episode_expert_usage)
        expert_usage_ratio = [usage / total_expert_usage for usage in episode_expert_usage]

        # Log test metrics to wandb
        wandb.log({
            "test_episode": episode,
            "test_total_reward": total_reward,
            "test_crashes": episode_crashes,
            "test_time": episode_time,
            "test_average_reward": total_reward / (step + 1),
            "test_total_crashes": total_crashes,
            "test_total_time": total_time,
            "test_episode_duration": episode_time,
            "test_experts_used": sum(1 for usage in episode_expert_usage if usage > 0),
        })

        for i, usage in enumerate(episode_expert_usage):
            wandb.log({
                f"test_expert_{i}_usage": usage,
                f"test_expert_{i}_usage_ratio": expert_usage_ratio[i]
            })

        print(f"Test Episode {episode}, Total Reward: {total_reward:.2f}, Crashes: {episode_crashes}, Time: {episode_time:.2f}s")

    avg_reward = sum(total_rewards) / len(total_rewards)
    print(f"Average Reward over {num_episodes} episodes: {avg_reward:.2f}")
    wandb.log({"test_average_reward_overall": avg_reward})

# The test_mixture_of_experts function remains the same

import warnings
warnings.filterwarnings("ignore")

if __name__ == "__main__":
    env = get_environment()
    n_actions = 3

    # Initialize wandb
    wandb.init(project="mixture-of-experts-dqn-alternating")

    # Load your three pre-trained expert agents
    expert1 = SimpleDQNAgent(n_actions)
    expert1.load_checkpoint("checkpoints_moe/episode_200/expert_0/checkpoint_episode_0_step_40000.pth")

    expert2 = SimpleDQNAgent(n_actions)
    expert2.load_checkpoint("checkpoints_moe/episode_200/expert_1/checkpoint_episode_0_step_46000.pth")

    expert3 = SimpleDQNAgent(n_actions)
    expert3.load_checkpoint("checkpoints_moe/episode_200/expert_2/checkpoint_episode_0_step_91000.pth")

    moe_agent = MixtureOfExpertsDQN([expert1, expert2, expert3])

    # Train the Mixture of Experts with alternating updates
    train_mixture_of_experts(env, moe_agent, num_episodes=4000, max_steps_per_episode=1000000)

    # Test the Mixture of Experts
    test_mixture_of_experts(env, moe_agent, num_episodes=100, max_steps_per_episode=5000)

    # Save the final model
    moe_agent.save_model("checkpoints_moe_alternating/final_model")

    # Close wandb run
    wandb.finish()
# Out:
# cuda
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: adamyvashisth (adamyvashisth-indian-institute-of-technology-roorkee). Use `wandb login --relogin` to force relogin
# wandb version 0.17.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>f:\fun\trackmania\wandb\run-20240908_020149-x79xznou</code>
# Syncing run <strong><a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-alternating/runs/x79xznou' target="_blank">misunderstood-vortex-7</a></strong> to <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-alternating' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-alternating' target="_blank">https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-alternating</a>
#  View run at <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-alternating/runs/x79xznou' target="_blank">https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-alternating/runs/x79xznou</a>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 292
#     289 wandb.init(project="mixture-of-experts-dqn-alternating")
#     291 # Load your three pre-trained expert agents
# --> 292 expert1 = SimpleDQNAgent(n_actions)
#     293 expert1.load_checkpoint("checkpoints_moe/episode_200/expert_0/checkpoint_episode_0_step_40000.pth")
#     295 expert2 = SimpleDQNAgent(n_actions)
#
# NameError: name 'SimpleDQNAgent' is not defined

# %%
import warnings
warnings.filterwarnings("ignore")
if __name__ == "__main__":
    env = get_environment()
    n_actions = 3

    # Initialize wandb
    wandb.init(project="mixture-of-experts-dqn-trial-2")

    # Load your three pre-trained expert agents
    expert1 = SimpleDQNAgent(n_actions)
    expert1.load_checkpoint("checkpoints_moe/episode_200/expert_0/checkpoint_episode_0_step_40000.pth")

    expert2 = SimpleDQNAgent(n_actions)
    expert2.load_checkpoint("checkpoints_moe/episode_200/expert_1/checkpoint_episode_0_step_46000.pth")

    expert3 = SimpleDQNAgent(n_actions)
    expert3.load_checkpoint("checkpoints_moe/episode_200/expert_2/checkpoint_episode_0_step_91000.pth")


    moe_agent=MixtureOfExpertsDQN([expert1,expert2,expert3])
    moe_agent.load_model(path="checkpoints_moe/final_model")

    # Train the Mixture of Experts
    train_mixture_of_experts(env, moe_agent, num_episodes=4000, max_steps_per_episode=1000000)

    # Test the Mixture of Experts
    test_mixture_of_experts(env, moe_agent, num_episodes=100, max_steps_per_episode=5000)

    # Save the final model
    moe_agent.save_model("checkpoints_moe/final_model")

    # Close wandb run
    wandb.finish()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: adamyvashisth (adamyvashisth-indian-institute-of-technology-roorkee). Use `wandb login --relogin` to force relogin
# wandb version 0.17.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>f:\fun\trackmania\wandb\run-20240908_014358-a6oet9af</code>
# Syncing run <strong><a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-trial-2/runs/a6oet9af' target="_blank">cosmic-frog-2</a></strong> to <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-trial-2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-trial-2' target="_blank">https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-trial-2</a>
#  View run at <a href='https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-trial-2/runs/a6oet9af' target="_blank">https://wandb.ai/adamyvashisth-indian-institute-of-technology-roorkee/mixture-of-experts-dqn-trial-2/runs/a6oet9af</a>
# Episode 0, Total Reward: -2.69, Crashes: 13, Time: 14.04s, Loss: 151.1328
# Checkpoint saved: checkpoints_moe_1/episode_0\expert_0\checkpoint_episode_0_step_40000.pth
# Checkpoint saved: checkpoints_moe_1/episode_0\expert_1\checkpoint_episode_0_step_46000.pth
# Checkpoint saved: checkpoints_moe_1/episode_0\expert_2\checkpoint_episode_0_step_91000.pth
# Episode 1, Total Reward: -3.71, Crashes: 7, Time: 10.07s, Loss: 70.5242
# Episode 2, Total Reward: -1.58, Crashes: 4, Time: 10.05s, Loss: 92.2249
# Episode 3, Total Reward: -0.53, Crashes: 2, Time: 9.95s, Loss: 53.6625
# Episode 4, Total Reward: 2.38, Crashes: 3, Time: 9.77s, Loss: 60.3140
# Episode 5, Total Reward: 2.54, Crashes: 2, Time: 10.17s, Loss: 53.7422
# Episode 6, Total Reward: -4.49, Crashes: 6, Time: 10.01s, Loss: 64.1602
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 25
#      22 moe_agent.load_model(path="checkpoints_moe/final_model")
#      24 # Train the Mixture of Experts
# ---> 25 train_mixture_of_experts(env, moe_agent, num_episodes=4000, max_steps_per_episode=1000000)
#      27 # Test the Mixture of Experts
#      28 test_mixture_of_experts(env, moe_agent, num_episodes=100, max_steps_per_episode=5000)
#
# Cell In[2], line 111, in train_mixture_of_experts(env, moe_agent, num_episodes, max_steps_per_episode)
#     108 expert_usage = [0] * moe_agent.num_experts
#     110 for episode in range(num_episodes):
# --> 111     obs, _ = env.reset()
#     112     state = preprocess_observation(obs)
#     113     total_reward = 0
#
# File d:\mini_conda\envs\collabkart\Lib\site-packages\gymnasium\core.py:467, in Wrapper.reset(self, seed, options)
#     463 def reset(
#     464     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     465 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     466     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 467     return self.env.reset(seed=seed, options=options)
#
# File d:\mini_conda\envs\collabkart\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:61, in OrderEnforcing.reset(self, **kwargs)
#      59 """Resets the environment with `kwargs`."""
#      60 self._has_reset = True
# ---> 61 return self.env.reset(**kwargs)
#
# File d:\mini_conda\envs\collabkart\Lib\site-packages\rtgym\envs\real_time_env.py:514, in RealTimeEnv.reset(self, seed, options)
#     512     if not self.last_act_on_reset:
#     513         self.act_buf[-1] = self.default_action
# --> 514 elt, info = self.interface.reset(seed=seed, options=options)
#     515 if self.act_in_obs:
#     516     elt = elt + list(self.act_buf)
#
# File d:\mini_conda\envs\collabkart\Lib\site-packages\tmrl\custom\custom_gym_interfaces.py:148, in TM2020Interface.reset(self, seed, options)
#     144 """
#     145 obs must be a list of numpy arrays
#     146 """
#     147 self.reset_common()
# --> 148 data, img = self.grab_data_and_img()
#     149 speed = np.array([
#     150     data[0],
#     151 ], dtype='float32')
#     152 gear = np.array([
#     153     data[9],
#     154 ], dtype='float32')
#
# File d:\mini_conda\envs\collabkart\Lib\site-packages\tmrl\custom\custom_gym_interfaces.py:118, in TM2020Interface.grab_data_and_img(self)
#     117 def grab_data_and_img(self):
# --> 118     img = self.window_interface.screenshot()[:, :, :3]  # BGR ordering
#     119     if self.resize_to is not None:  # cv2.resize takes dim as (width, height)
#     120         img = cv2.resize(img, self.resize_to)
#
# File d:\mini_conda\envs\collabkart\Lib\site-packages\tmrl\custom\utils\window.py:43, in WindowInterface.screenshot(self)
#      40 assert hwnd != 0, f"Could not find a window named {self.window_name}."
#      42 while True:  # avoids crashes when the window is reduced
# ---> 43     x, y, x1, y1 = win32gui.GetWindowRect(hwnd)
#      44     w = x1 - x - self.w_diff
#      45     h = y1 - y - self.h_diff
#
# KeyboardInterrupt:

# %%
wandb.init(project="mixture-of-experts-dqn-trial-1")
env = get_environment()
n_actions=3
expert1 = SimpleDQNAgent(n_actions)
expert1.load_checkpoint("checkpoints_moe/episode_200/expert_0/checkpoint_episode_0_step_40000.pth")

expert2 = SimpleDQNAgent(n_actions)
expert2.load_checkpoint("checkpoints_moe/episode_200/expert_1/checkpoint_episode_0_step_46000.pth")

expert3 = SimpleDQNAgent(n_actions)
expert3.load_checkpoint("checkpoints_moe/episode_200/expert_2/checkpoint_episode_0_step_91000.pth")


moe_agent=MixtureOfExpertsDQN([expert1,expert2,expert3])
moe_agent.load_model(path="checkpoints_moe/final_model")
test_mixture_of_experts(env, moe_agent, num_episodes=1000, max_steps_per_episode=1000000)
